# %%
import pandas as pd
import numpy as np
import os
# ast - Abstract Syntax Tree - processes trees of the Python abstract syntax grammar.
import ast

# %%
recipe_df1 = pd.read_csv('ScrapeData/csv_recipes/recipe_df1.csv',low_memory=False)
recipe_df2 = pd.read_csv('ScrapeData/csv_recipes/recipe_df2.csv',low_memory=False)
recipe_df3 = pd.read_csv('ScrapeData/csv_recipes/recipe_df3.csv',low_memory=False)
recipe_df4 = pd.read_csv('ScrapeData/csv_recipes/recipe_df4.csv',low_memory=False)
recipe_df5 = pd.read_csv('ScrapeData/csv_recipes/recipe_df5.csv',low_memory=False)

# %%
# Add merge all df into one df. 
# test = [recipe_df1, recipe_df2,recipe_df3, recipe_df4, recipe_df5]
all_recipes = pd.concat([recipe_df1, recipe_df2,recipe_df3, recipe_df4, recipe_df5],ignore_index=True)

# %%
all_recipes.head()
# Out:
#    Unnamed: 0  bestrating  id  \
# 0         0.0         4.0 NaN
# 1         1.0         4.0 NaN
# 2         2.0         4.0 NaN
# 3         3.0         4.0 NaN
# 4         4.0         4.0 NaN
#
#                                             imagesrc  \
# 0  https://assets.epicurious.com/photos/56df1d8cb...
# 1  https://assets.epicurious.com/photos/5a78b5919...
# 2  https://assets.epicurious.com/photos/5a68f33b3...
# 3  https://assets.epicurious.com/photos/5a9971b01...
# 4  https://assets.epicurious.com/photos/54b71d9a2...
#
#                                          ingredients makeitagainscore  \
# 0  ['2 cups whole-wheat flour', '2 cups all-purpo...              90%
# 1  ['1 Tbsp. crushed red pepper flakes', '1 Tbsp....              91%
# 2  ['1/4 cup extra-virgin olive oil', '12 oz. dry...              67%
# 3  ['1 tablespoon olive oil', '2 garlic cloves, t...              81%
# 4  ['1 1/2 pounds boneless, skinless chicken brea...              96%
#
#                                          preparation  rating  reviews  \
# 0  Put oven rack in middle position and preheat o...     3.5     50.0
# 1  Coarsely grind red pepper flakes, peppercorns,...     3.0     11.0
# 2  Pour oil into cooker insert and select “Sauté....     2.0     15.0
# 3  Preheat oven to 350°F. Heat oil in a large ski...     3.5     26.0
# 4  Place chicken, garlic, bay leaves, allspice, a...     3.5     23.0
#
#                                                 tags  \
# 0  ['Irish', 'Bread', 'Bake', 'Vegetarian', 'Quic...
# 1  ['Pepper', 'Fennel', 'Pork', 'Garlic', 'White ...
# 2  ['Instant Pot', 'Kale', 'Potato', 'Onion', 'Ga...
# 3  ['Side', 'Bake', 'Christmas', 'Easter', 'Thank...
# 4  ['Asian', 'Soup/Stew', 'Chicken', 'Low Carb', ...
#
#                                                title
# 0                                 Irish Brown Bread
# 1                   Slow-Cooked Pork with Chickpeas
# 2                           Instant Pot Caldo Verde
# 3  Parmesan Bread Pudding with Broccoli Rabe and ...
# 4  Brothy Poached Chicken with Mushrooms and Fres...

# %%
all_recipes.count()
# Out:
# Unnamed: 0          4858
# bestrating          6662
# id                  1816
# imagesrc            5016
# ingredients         6674
# makeitagainscore    6662
# preparation         6672
# rating              6662
# reviews             6662
# tags                6646
# title               6673
# dtype: int64

# %%
all_recipes.columns
# Out:
# Index(['Unnamed: 0', 'bestrating', 'id', 'imagesrc', 'ingredients',
#        'makeitagainscore', 'preparation', 'rating', 'reviews', 'tags',
#        'title'],
#       dtype='object')

# %%
# Drop Unnamed and id columns before we dropping rows with empty cells.
all_recipes.drop('Unnamed: 0',axis=1, inplace=True)
all_recipes.drop('id',axis=1, inplace=True)

# %%
all_recipes.count()
# Out:
# bestrating          6662
# imagesrc            5016
# ingredients         6674
# makeitagainscore    6662
# preparation         6672
# rating              6662
# reviews             6662
# tags                6646
# title               6673
# dtype: int64

# %%
all_clean_recipes = all_recipes.dropna(axis=0, how="any")

# %%
all_clean_recipes.count()
# Out:
# bestrating          4990
# imagesrc            4990
# ingredients         4990
# makeitagainscore    4990
# preparation         4990
# rating              4990
# reviews             4990
# tags                4990
# title               4990
# dtype: int64

# %%
# ast.literal_eval = Safely evaluates an expression node or a Unicode
# or Latin-1 encoded string containing a Python literal. 
# The string or node provided may only consist of the following 
# Python literal structures: strings, numbers, tuples, lists, dicts, booleans, and None.
all_tags = []
for index, row in all_clean_recipes.iterrows():
    tags = ast.literal_eval(row["tags"])
    for tag in tags:
        all_tags.append(tag)

# %%
# All the tags
len(all_tags)
# Out:
# 75836

# %%
# Get unigue tags and remove duplicates. 
def getUniqueTags(allTags):
    uniqueTags = [] 
    for i in allTags:
        if not i in uniqueTags:
            uniqueTags.append(i)
    return uniqueTags

tags = getUniqueTags(all_tags)

# %%
# All the unique tags
len(tags)
# Out:
# 633

# %%
for tag in tags:
    print(tag)
# Out:
# Irish
# Bread
# Bake
# Vegetarian
# Quick & Easy
# St. Patrick's Day
# Spring
# Gourmet
# Pepper
# Fennel
# Pork
# Garlic
# White Wine
# Onion
# Chickpea
# Parsley
# Winter
# Dinner
# Entertaining
# Wheat/Gluten-Free
# Instant Pot
# Kale
# Potato
# Soup/Stew
# Sausage
# Spanish/Portuguese
# Side
# Christmas
# Easter
# Thanksgiving
# Casserole/Gratin
# Parmesan
# Ham
# Broccoli Rabe
# Bon Appétit
# Peanut Free
# Tree Nut Free
# Soy Free
# Asian
# Chicken
# Low Carb
# Low Fat
# Kid-Friendly
# Low Cal
# Lunch
# Healthy
# Boil
# Quick and Healthy
# Pasta
# Arugula
# Capers
# Cauliflower
# Lemon Juice
# Fruit Juice
# Mustard
# Buffet
# Southern
# Apple
# Honey
# Dairy Free
# Cornmeal
# Cheese
# Italian American
# Italian
# Lentil
# Curry
# Ginger
# Coconut
# Tomato
# Cilantro
# Breakfast
# Egg
# Yogurt
# Green Onion/Scallion
# Spinach
# Cheddar
# Brunch
# Small Plates
# Mint
# Pork Tenderloin
# Peanut
# Brussels Sprout
# Soy Sauce
# Chile Pepper
# Dessert
# Cake
# Spice
# Fall
# Walnut
# Cinnamon
# Nutmeg
# Butterscotch/Caramel
# Tarragon
# French
# Lemon
# Shallot
# Braise
# Rosemary
# Cast Iron
# Squash
# Roast
# Milk/Cream
# Leafy Green
# High Fiber
# Collard Greens
# Middle Eastern
# Pecan
# Orange
# Phyllo/Puff Pastry Dough
# Bourbon
# Butter
# Pie
# Raisin
# Latin American
# South American
# Gluten-Free and Fresh
# Hominy/Cornmeal/Masa
# Cumin
# Ground Beef
# Beef
# Jalapeño
# Corn
# Southwestern
# American
# One-Pot Meal
# Thyme
# Dinner 1-2-3
# Thai
# turkey
# Meatball
# Noodle
# Sugar Snap Pea
# Bell Pepper
# Seafood
# Fish
# Salmon
# Summer
# Poach
# 22-Minute Meals
# Takeout at Home
# Chinese
# Pineapple
# Chocolate
# Mother's Day
# Banana
# Cookie
# Vegan
# Pescatarian
# Kosher
# Freeze/Chill
# Frozen Dessert
# Muffin
# Blueberry
# Sour Cream
# Tropical Fruit
# Grill
# Grill/Barbecue
# Shrimp
# Zucchini
# Feta
# Oregano
# Greek
# 3-Ingredient Recipes
# Basil
# Peach
# Yellow Squash
# Olive
# Clam
# Shellfish
# Beer
# Hot Pepper
# Food Processor
# Dairy
# Vegetable
# Herb
# Ricotta
# No Sugar Added
# Rice
# Lime Juice
# Cardamom
# Cucumber
# Pistachio
# Brownie
# snack
# Gin
# Alcoholic
# Cocktail Party
# Shower
# Drink
# Kidney Friendly
# Cream Cheese
# Raspberry
# Cookies
# Mixer
# Family Reunion
# Fruit
# Fry
# Diabetes-Friendly
# Backyard BBQ
# Sugar Conscious
# Paleo
# Bacon
# Maple Syrup
# Waffle
# HarperCollins
# Almond
# Fourth of July
# Picnic
# Father's Day
# Horseradish
# Meat
# Steak
# Root Vegetable
# Tailgating
# Party
# 30 Days of Groceries
# Pot Pie
# Leek
# Pea
# Radish
# Appetizer
# Artichoke
# Pork Chop
# Mustard Greens
# Condiment/Spread
# Asparagus
# Butternut Squash
# Pomegranate
# Orzo
# Mushroom
# Sauté
# Potluck
# Mozzarella
# Orange Juice
# Strawberry
# White Chocolate
# Passover
# Kosher for Passover
# Carrot
# Prune
# Apricot
# Dried Fruit
# Salad
# Lettuce
# Anchovy
# #cook90
# Frittata
# Rosh Hashanah/Yom Kippur
# Moroccan
# African
# Jewish
# Jam or Jelly
# Oat
# Frankenrecipe
# Meatloaf
# Breadcrumbs
# Valentine's Day
# New Year's Day
# Pastry
# No Meat, No Problem
# Bean
# Sage
# Wine
# Dark Chocolate
# Cheese Week
# Sandwich
# No-Cook
# Tuna
# Cajun/Creole
# Mardi Gras
# Vinegar
# Dill
# Fat Free
# Peanut Butter
# Microwave
# Tex-Mex
# Tortillas
# Sweet Potato/Yam
# Mediterranean
# Avocado
# Indian
# Cabbage
# South Asian
# Lamb
# Coriander
# Sesame
# Lasagna
# Pressure Cooker
# Vietnamese
# Southeast Asian
# Anise
# Clove
# Lime
# Grapefruit
# Drinks
# Non-Alcoholic
# Stew
# Escarole
# Couscous
# Grains
# Quinoa
# Barley
# Sesame Oil
# House Cocktail
# New Year's Eve
# Champagne
# Citrus
# Sparkling Wine
# Cocktail
# Currant
# Paprika
# Cod
# English
# British
# Cognac/Armagnac
# Parsnip
# Hazelnut
# Cranberry
# Goat Cheese
# Tofu
# Dip
# Hanukkah
# Seed
# Poppy
# Pumpkin
# Turnip
# Pancake
# Chili
# Bok Choy
# Tart
# Chard
# Prosciutto
# Korean
# Alabama
# Broccoli
# Pine Nut
# Freezer Food
# Midwestern
# Michigan
# Whiskey
# Rye
# Bitters
# Macaroni and Cheese
# Japanese
# Sourdough
# Flaming Hot Summer
# Eggplant
# Green Bean
# Labor Day
# Vanilla
# Chill
# Beet
# Eastern European/Russian
# European
# Birthday
# Buttermilk
# Wedding
# Skewer
# Hamburger
# Coffee
# Iced Coffee
# Cook Like a Diner
# #CAKEWEEK
# Amaretto
# Plum
# Brown Rice
# Mexican
# Taco
# Marinate
# Chive
# Graduation
# Granola
# Cherry
# Monterey Jack
# Broil
# Semolina
# Lemongrass
# Date
# Whole Wheat
# Brisket
# Pomegranate Juice
# Candy
# Back to School
# Chile
# snack week
# Hot Drink
# Oscars
# Christmas Eve
# Quiche
# Vodka
# New Orleans
# Hors D'Oeuvre
# Scandinavian
# Low Cholesterol
# cookbooks
# Stuffing/Dressing
# Biscuit
# Smoothie
# Grape
# Snapper
# Super Bowl
# Beef Rib
# Tomatillo
# Tea
# Pear
# Anniversary
# Dallas
# Texas
# Portland
# Oregon
# South Carolina
# Lamb Chop
# Celery
# Pork Rib
# Low/No Sugar
# German
# New York
# Bronx
# Rhubarb
# Organic
# Veal
# Red Wine
# Fontina
# Berry
# Low Sodium
# Ground Lamb
# Southern Italian
# Ramekin
# Cashew
# Trout
# Blackberry
# Condiment
# Healdsburg
# Weelicious
# Stir-Fry
# Sauce
# Mayonnaise
# Deep-Fry
# Halloween
# Halibut
# Poultry
# Coffee Grinder
# Turkish
# Mussel
# Squid
# Central/South American
# Pan-Fry
# Houston
# Swiss Cheese
# Pennsylvania
# Raw
# Watermelon
# Lobster
# Sake
# Sandwich Theory
# Tilapia
# Scallop
# Salad Dressing
# Self
# Massachusetts
# Radicchio
# Advance Prep Required
# Slow Cooker
# Simmer
# Soy
# Israeli
# Lunar New Year
# Edible Gift
# Engagement Party
# Bulgur
# Atlanta
# Georgia
# Cinco de Mayo
# Poker/Game Night
# Tangerine
# Nut
# Tree Nut
# Wild Rice
# Legume
# Saffron
# Sukkot
# Marshmallow
# Watercress
# Candy Thermometer
# Molasses
# Central American/Caribbean
# Rum
# Egg Nog
# Oatmeal
# Duck
# Jerusalem Artichoke
# Mandoline
# Blue Cheese
# Bass
# Cuban
# Lima Bean
# Californian
# Nectarine
# Smoker
# Mango
# Apple Juice
# Cottage Cheese
# French Provençal
# Wok
# Ramadan
# Tequila
# Spirit
# Bon App��tit
# Fig
# Caraway
# Crab
# New England
# Blender
# Steam
# Pasta Maker
# Melon
# Brine
# Bastille Day
# Liqueur
# Sauce Secrets
# Canadian
# Persimmon
# Okra
# Endive
# Brandy
# Beef Tenderloin
# Double Boiler
# Kentucky Derby
# Ice Cream Machine
# Argentine
# Margarita
# Marzipan
# Plantain
# Poultry Sausage
# Asian Pear
# Lamb Shank
# Central Asian
# Persian New Year
# Passion Fruit
# Gouda
# Rutabaga
# Swordfish
# Mortar and Pestle
# Marscarpone
# Brazilian
# Vermouth
# Spritzer
# Sherry
# Buffalo
# Sardine
# Port
# Calvados
# Beef Shank
# Marsala
# Macadamia Nut
# Grand Marnier
# Chestnut
# Parade
# Oktoberfest
# Oyster
# Ethiopian
# Canada
# Poblano
# Honeydew
# Tapioca
# Australian/New Zealand
# Indonesian
# Diwali
# Sangria
# Guava
# Northern Italian
# Basque
# Sephardic
# Rack of Lamb
# Tamarind
# Kiwi
# Ashkenazi
# Brie
# Nuevo Latino
# Seattle
# Washington
# Kumquat
# Triple Sec
# Szechuan/Hunan
# Fortified Wine
# Punch
# Campari
# Mexico
# India
# Greece
# California
# Brooklyn
# Marrakech
# Morocco
# Kwanzaa
# Frangelico
# Indiana
# Shavuot
# Pernod
# Martini
# Lychee
# Colorado
# Game
# Rabbit
# New Mexico
# New Jersey
# Quince
# Cantaloupe
# Pittsburgh
# Los Angeles
# Rosé
# Purim
# Pasadena
# Ohio
# Yonkers
# Aperitif
# Arizona
# Sushi
# Wasabi
# Wisconsin
# San Francisco
# Papaya
# Eau de Vie
# Grappa
# Scotch
# Jícama
# Pacific Northwest
# Venison
# Pizza
# Virginia
# Goose
# Kirsch
# Quail

# %%
# Convert the list to a dictionary
tags_dict = {k: v for k, v in enumerate(tags)}

# %%
tags_dict
# Out:
# {0: 'Irish',
#  1: 'Bread',
#  2: 'Bake',
#  3: 'Vegetarian',
#  4: 'Quick & Easy',
#  5: "St. Patrick's Day",
#  6: 'Spring',
#  7: 'Gourmet',
#  8: 'Pepper',
#  9: 'Fennel',
#  10: 'Pork',
#  11: 'Garlic',
#  12: 'White Wine',
#  13: 'Onion',
#  14: 'Chickpea',
#  15: 'Parsley',
#  16: 'Winter',
#  17: 'Dinner',
#  18: 'Entertaining',
#  19: 'Wheat/Gluten-Free',
#  20: 'Instant Pot',
#  21: 'Kale',
#  22: 'Potato',
#  23: 'Soup/Stew',
#  24: 'Sausage',
#  25: 'Spanish/Portuguese',
#  26: 'Side',
#  27: 'Christmas',
#  28: 'Easter',
#  29: 'Thanksgiving',
#  30: 'Casserole/Gratin',
#  31: 'Parmesan',
#  32: 'Ham',
#  33: 'Broccoli Rabe',
#  34: 'Bon Appétit',
#  35: 'Peanut Free',
#  36: 'Tree Nut Free',
#  37: 'Soy Free',
#  38: 'Asian',
#  39: 'Chicken',
#  40: 'Low Carb',
#  41: 'Low Fat',
#  42: 'Kid-Friendly',
#  43: 'Low Cal',
#  44: 'Lunch',
#  45: 'Healthy',
#  46: 'Boil',
#  47: 'Quick and Healthy',
#  48: 'Pasta',
#  49: 'Arugula',
#  50: 'Capers',
#  51: 'Cauliflower',
#  52: 'Lemon Juice',
#  53: 'Fruit Juice',
#  54: 'Mustard',
#  55: 'Buffet',
#  56: 'Southern',
#  57: 'Apple',
#  58: 'Honey',
#  59: 'Dairy Free',
#  60: 'Cornmeal',
#  61: 'Cheese',
#  62: 'Italian American',
#  63: 'Italian',
#  64: 'Lentil',
#  65: 'Curry',
#  66: 'Ginger',
#  67: 'Coconut',
#  68: 'Tomato',
#  69: 'Cilantro',
#  70: 'Breakfast',
#  71: 'Egg',
#  72: 'Yogurt',
#  73: 'Green Onion/Scallion',
#  74: 'Spinach',
#  75: 'Cheddar',
#  76: 'Brunch',
#  77: 'Small Plates',
#  78: 'Mint',
#  79: 'Pork Tenderloin',
#  80: 'Peanut',
#  81: 'Brussels Sprout',
#  82: 'Soy Sauce',
#  83: 'Chile Pepper',
#  84: 'Dessert',
#  85: 'Cake',
#  86: 'Spice',
#  87: 'Fall',
#  88: 'Walnut',
#  89: 'Cinnamon',
#  90: 'Nutmeg',
#  91: 'Butterscotch/Caramel',
#  92: 'Tarragon',
#  93: 'French',
#  94: 'Lemon',
#  95: 'Shallot',
#  96: 'Braise',
#  97: 'Rosemary',
#  98: 'Cast Iron',
#  99: 'Squash',
#  100: 'Roast',
#  101: 'Milk/Cream',
#  102: 'Leafy Green',
#  103: 'High Fiber',
#  104: 'Collard Greens',
#  105: 'Middle Eastern',
#  106: 'Pecan',
#  107: 'Orange',
#  108: 'Phyllo/Puff Pastry Dough',
#  109: 'Bourbon',
#  110: 'Butter',
#  111: 'Pie',
#  112: 'Raisin',
#  113: 'Latin American',
#  114: 'South American',
#  115: 'Gluten-Free and Fresh',
#  116: 'Hominy/Cornmeal/Masa',
#  117: 'Cumin',
#  118: 'Ground Beef',
#  119: 'Beef',
#  120: 'Jalapeño',
#  121: 'Corn',
#  122: 'Southwestern',
#  123: 'American',
#  124: 'One-Pot Meal',
#  125: 'Thyme',
#  126: 'Dinner 1-2-3',
#  127: 'Thai',
#  128: 'turkey',
#  129: 'Meatball',
#  130: 'Noodle',
#  131: 'Sugar Snap Pea',
#  132: 'Bell Pepper',
#  133: 'Seafood',
#  134: 'Fish',
#  135: 'Salmon',
#  136: 'Summer',
#  137: 'Poach',
#  138: '22-Minute Meals',
#  139: 'Takeout at Home',
#  140: 'Chinese',
#  141: 'Pineapple',
#  142: 'Chocolate',
#  143: "Mother's Day",
#  144: 'Banana',
#  145: 'Cookie',
#  146: 'Vegan',
#  147: 'Pescatarian',
#  148: 'Kosher',
#  149: 'Freeze/Chill',
#  150: 'Frozen Dessert',
#  151: 'Muffin',
#  152: 'Blueberry',
#  153: 'Sour Cream',
#  154: 'Tropical Fruit',
#  155: 'Grill',
#  156: 'Grill/Barbecue',
#  157: 'Shrimp',
#  158: 'Zucchini',
#  159: 'Feta',
#  160: 'Oregano',
#  161: 'Greek',
#  162: '3-Ingredient Recipes',
#  163: 'Basil',
#  164: 'Peach',
#  165: 'Yellow Squash',
#  166: 'Olive',
#  167: 'Clam',
#  168: 'Shellfish',
#  169: 'Beer',
#  170: 'Hot Pepper',
#  171: 'Food Processor',
#  172: 'Dairy',
#  173: 'Vegetable',
#  174: 'Herb',
#  175: 'Ricotta',
#  176: 'No Sugar Added',
#  177: 'Rice',
#  178: 'Lime Juice',
#  179: 'Cardamom',
#  180: 'Cucumber',
#  181: 'Pistachio',
#  182: 'Brownie',
#  183: 'snack',
#  184: 'Gin',
#  185: 'Alcoholic',
#  186: 'Cocktail Party',
#  187: 'Shower',
#  188: 'Drink',
#  189: 'Kidney Friendly',
#  190: 'Cream Cheese',
#  191: 'Raspberry',
#  192: 'Cookies',
#  193: 'Mixer',
#  194: 'Family Reunion',
#  195: 'Fruit',
#  196: 'Fry',
#  197: 'Diabetes-Friendly',
#  198: 'Backyard BBQ',
#  199: 'Sugar Conscious',
#  200: 'Paleo',
#  201: 'Bacon',
#  202: 'Maple Syrup',
#  203: 'Waffle',
#  204: 'HarperCollins',
#  205: 'Almond',
#  206: 'Fourth of July',
#  207: 'Picnic',
#  208: "Father's Day",
#  209: 'Horseradish',
#  210: 'Meat',
#  211: 'Steak',
#  212: 'Root Vegetable',
#  213: 'Tailgating',
#  214: 'Party',
#  215: '30 Days of Groceries',
#  216: 'Pot Pie',
#  217: 'Leek',
#  218: 'Pea',
#  219: 'Radish',
#  220: 'Appetizer',
#  221: 'Artichoke',
#  222: 'Pork Chop',
#  223: 'Mustard Greens',
#  224: 'Condiment/Spread',
#  225: 'Asparagus',
#  226: 'Butternut Squash',
#  227: 'Pomegranate',
#  228: 'Orzo',
#  229: 'Mushroom',
#  230: 'Sauté',
#  231: 'Potluck',
#  232: 'Mozzarella',
#  233: 'Orange Juice',
#  234: 'Strawberry',
#  235: 'White Chocolate',
#  236: 'Passover',
#  237: 'Kosher for Passover',
#  238: 'Carrot',
#  239: 'Prune',
#  240: 'Apricot',
#  241: 'Dried Fruit',
#  242: 'Salad',
#  243: 'Lettuce',
#  244: 'Anchovy',
#  245: '#cook90',
#  246: 'Frittata',
#  247: 'Rosh Hashanah/Yom Kippur',
#  248: 'Moroccan',
#  249: 'African',
#  250: 'Jewish',
#  251: 'Jam or Jelly',
#  252: 'Oat',
#  253: 'Frankenrecipe',
#  254: 'Meatloaf',
#  255: 'Breadcrumbs',
#  256: "Valentine's Day",
#  257: "New Year's Day",
#  258: 'Pastry',
#  259: 'No Meat, No Problem',
#  260: 'Bean',
#  261: 'Sage',
#  262: 'Wine',
#  263: 'Dark Chocolate',
#  264: 'Cheese Week',
#  265: 'Sandwich',
#  266: 'No-Cook',
#  267: 'Tuna',
#  268: 'Cajun/Creole',
#  269: 'Mardi Gras',
#  270: 'Vinegar',
#  271: 'Dill',
#  272: 'Fat Free',
#  273: 'Peanut Butter',
#  274: 'Microwave',
#  275: 'Tex-Mex',
#  276: 'Tortillas',
#  277: 'Sweet Potato/Yam',
#  278: 'Mediterranean',
#  279: 'Avocado',
#  280: 'Indian',
#  281: 'Cabbage',
#  282: 'South Asian',
#  283: 'Lamb',
#  284: 'Coriander',
#  285: 'Sesame',
#  286: 'Lasagna',
#  287: 'Pressure Cooker',
#  288: 'Vietnamese',
#  289: 'Southeast Asian',
#  290: 'Anise',
#  291: 'Clove',
#  292: 'Lime',
#  293: 'Grapefruit',
#  294: 'Drinks',
#  295: 'Non-Alcoholic',
#  296: 'Stew',
#  297: 'Escarole',
#  298: 'Couscous',
#  299: 'Grains',
#  300: 'Quinoa',
#  301: 'Barley',
#  302: 'Sesame Oil',
#  303: 'House Cocktail',
#  304: "New Year's Eve",
#  305: 'Champagne',
#  306: 'Citrus',
#  307: 'Sparkling Wine',
#  308: 'Cocktail',
#  309: 'Currant',
#  310: 'Paprika',
#  311: 'Cod',
#  312: 'English',
#  313: 'British',
#  314: 'Cognac/Armagnac',
#  315: 'Parsnip',
#  316: 'Hazelnut',
#  317: 'Cranberry',
#  318: 'Goat Cheese',
#  319: 'Tofu',
#  320: 'Dip',
#  321: 'Hanukkah',
#  322: 'Seed',
#  323: 'Poppy',
#  324: 'Pumpkin',
#  325: 'Turnip',
#  326: 'Pancake',
#  327: 'Chili',
#  328: 'Bok Choy',
#  329: 'Tart',
#  330: 'Chard',
#  331: 'Prosciutto',
#  332: 'Korean',
#  333: 'Alabama',
#  334: 'Broccoli',
#  335: 'Pine Nut',
#  336: 'Freezer Food',
#  337: 'Midwestern',
#  338: 'Michigan',
#  339: 'Whiskey',
#  340: 'Rye',
#  341: 'Bitters',
#  342: 'Macaroni and Cheese',
#  343: 'Japanese',
#  344: 'Sourdough',
#  345: 'Flaming Hot Summer',
#  346: 'Eggplant',
#  347: 'Green Bean',
#  348: 'Labor Day',
#  349: 'Vanilla',
#  350: 'Chill',
#  351: 'Beet',
#  352: 'Eastern European/Russian',
#  353: 'European',
#  354: 'Birthday',
#  355: 'Buttermilk',
#  356: 'Wedding',
#  357: 'Skewer',
#  358: 'Hamburger',
#  359: 'Coffee',
#  360: 'Iced Coffee',
#  361: 'Cook Like a Diner',
#  362: '#CAKEWEEK',
#  363: 'Amaretto',
#  364: 'Plum',
#  365: 'Brown Rice',
#  366: 'Mexican',
#  367: 'Taco',
#  368: 'Marinate',
#  369: 'Chive',
#  370: 'Graduation',
#  371: 'Granola',
#  372: 'Cherry',
#  373: 'Monterey Jack',
#  374: 'Broil',
#  375: 'Semolina',
#  376: 'Lemongrass',
#  377: 'Date',
#  378: 'Whole Wheat',
#  379: 'Brisket',
#  380: 'Pomegranate Juice',
#  381: 'Candy',
#  382: 'Back to School',
#  383: 'Chile',
#  384: 'snack week',
#  385: 'Hot Drink',
#  386: 'Oscars',
#  387: 'Christmas Eve',
#  388: 'Quiche',
#  389: 'Vodka',
#  390: 'New Orleans',
#  391: "Hors D'Oeuvre",
#  392: 'Scandinavian',
#  393: 'Low Cholesterol',
#  394: 'cookbooks',
#  395: 'Stuffing/Dressing',
#  396: 'Biscuit',
#  397: 'Smoothie',
#  398: 'Grape',
#  399: 'Snapper',
#  400: 'Super Bowl',
#  401: 'Beef Rib',
#  402: 'Tomatillo',
#  403: 'Tea',
#  404: 'Pear',
#  405: 'Anniversary',
#  406: 'Dallas',
#  407: 'Texas',
#  408: 'Portland',
#  409: 'Oregon',
#  410: 'South Carolina',
#  411: 'Lamb Chop',
#  412: 'Celery',
#  413: 'Pork Rib',
#  414: 'Low/No Sugar',
#  415: 'German',
#  416: 'New York',
#  417: 'Bronx',
#  418: 'Rhubarb',
#  419: 'Organic',
#  420: 'Veal',
#  421: 'Red Wine',
#  422: 'Fontina',
#  423: 'Berry',
#  424: 'Low Sodium',
#  425: 'Ground Lamb',
#  426: 'Southern Italian',
#  427: 'Ramekin',
#  428: 'Cashew',
#  429: 'Trout',
#  430: 'Blackberry',
#  431: 'Condiment',
#  432: 'Healdsburg',
#  433: 'Weelicious',
#  434: 'Stir-Fry',
#  435: 'Sauce',
#  436: 'Mayonnaise',
#  437: 'Deep-Fry',
#  438: 'Halloween',
#  439: 'Halibut',
#  440: 'Poultry',
#  441: 'Coffee Grinder',
#  442: 'Turkish',
#  443: 'Mussel',
#  444: 'Squid',
#  445: 'Central/South American',
#  446: 'Pan-Fry',
#  447: 'Houston',
#  448: 'Swiss Cheese',
#  449: 'Pennsylvania',
#  450: 'Raw',
#  451: 'Watermelon',
#  452: 'Lobster',
#  453: 'Sake',
#  454: 'Sandwich Theory',
#  455: 'Tilapia',
#  456: 'Scallop',
#  457: 'Salad Dressing',
#  458: 'Self',
#  459: 'Massachusetts',
#  460: 'Radicchio',
#  461: 'Advance Prep Required',
#  462: 'Slow Cooker',
#  463: 'Simmer',
#  464: 'Soy',
#  465: 'Israeli',
#  466: 'Lunar New Year',
#  467: 'Edible Gift',
#  468: 'Engagement Party',
#  469: 'Bulgur',
#  470: 'Atlanta',
#  471: 'Georgia',
#  472: 'Cinco de Mayo',
#  473: 'Poker/Game Night',
#  474: 'Tangerine',
#  475: 'Nut',
#  476: 'Tree Nut',
#  477: 'Wild Rice',
#  478: 'Legume',
#  479: 'Saffron',
#  480: 'Sukkot',
#  481: 'Marshmallow',
#  482: 'Watercress',
#  483: 'Candy Thermometer',
#  484: 'Molasses',
#  485: 'Central American/Caribbean',
#  486: 'Rum',
#  487: 'Egg Nog',
#  488: 'Oatmeal',
#  489: 'Duck',
#  490: 'Jerusalem Artichoke',
#  491: 'Mandoline',
#  492: 'Blue Cheese',
#  493: 'Bass',
#  494: 'Cuban',
#  495: 'Lima Bean',
#  496: 'Californian',
#  497: 'Nectarine',
#  498: 'Smoker',
#  499: 'Mango',
#  500: 'Apple Juice',
#  501: 'Cottage Cheese',
#  502: 'French Provençal',
#  503: 'Wok',
#  504: 'Ramadan',
#  505: 'Tequila',
#  506: 'Spirit',
#  507: 'Bon App��tit',
#  508: 'Fig',
#  509: 'Caraway',
#  510: 'Crab',
#  511: 'New England',
#  512: 'Blender',
#  513: 'Steam',
#  514: 'Pasta Maker',
#  515: 'Melon',
#  516: 'Brine',
#  517: 'Bastille Day',
#  518: 'Liqueur',
#  519: 'Sauce Secrets',
#  520: 'Canadian',
#  521: 'Persimmon',
#  522: 'Okra',
#  523: 'Endive',
#  524: 'Brandy',
#  525: 'Beef Tenderloin',
#  526: 'Double Boiler',
#  527: 'Kentucky Derby',
#  528: 'Ice Cream Machine',
#  529: 'Argentine',
#  530: 'Margarita',
#  531: 'Marzipan',
#  532: 'Plantain',
#  533: 'Poultry Sausage',
#  534: 'Asian Pear',
#  535: 'Lamb Shank',
#  536: 'Central Asian',
#  537: 'Persian New Year',
#  538: 'Passion Fruit',
#  539: 'Gouda',
#  540: 'Rutabaga',
#  541: 'Swordfish',
#  542: 'Mortar and Pestle',
#  543: 'Marscarpone',
#  544: 'Brazilian',
#  545: 'Vermouth',
#  546: 'Spritzer',
#  547: 'Sherry',
#  548: 'Buffalo',
#  549: 'Sardine',
#  550: 'Port',
#  551: 'Calvados',
#  552: 'Beef Shank',
#  553: 'Marsala',
#  554: 'Macadamia Nut',
#  555: 'Grand Marnier',
#  556: 'Chestnut',
#  557: 'Parade',
#  558: 'Oktoberfest',
#  559: 'Oyster',
#  560: 'Ethiopian',
#  561: 'Canada',
#  562: 'Poblano',
#  563: 'Honeydew',
#  564: 'Tapioca',
#  565: 'Australian/New Zealand',
#  566: 'Indonesian',
#  567: 'Diwali',
#  568: 'Sangria',
#  569: 'Guava',
#  570: 'Northern Italian',
#  571: 'Basque',
#  572: 'Sephardic',
#  573: 'Rack of Lamb',
#  574: 'Tamarind',
#  575: 'Kiwi',
#  576: 'Ashkenazi',
#  577: 'Brie',
#  578: 'Nuevo Latino',
#  579: 'Seattle',
#  580: 'Washington',
#  581: 'Kumquat',
#  582: 'Triple Sec',
#  583: 'Szechuan/Hunan',
#  584: 'Fortified Wine',
#  585: 'Punch',
#  586: 'Campari',
#  587: 'Mexico',
#  588: 'India',
#  589: 'Greece',
#  590: 'California',
#  591: 'Brooklyn',
#  592: 'Marrakech',
#  593: 'Morocco',
#  594: 'Kwanzaa',
#  595: 'Frangelico',
#  596: 'Indiana',
#  597: 'Shavuot',
#  598: 'Pernod',
#  599: 'Martini',
#  600: 'Lychee',
#  601: 'Colorado',
#  602: 'Game',
#  603: 'Rabbit',
#  604: 'New Mexico',
#  605: 'New Jersey',
#  606: 'Quince',
#  607: 'Cantaloupe',
#  608: 'Pittsburgh',
#  609: 'Los Angeles',
#  610: 'Rosé',
#  611: 'Purim',
#  612: 'Pasadena',
#  613: 'Ohio',
#  614: 'Yonkers',
#  615: 'Aperitif',
#  616: 'Arizona',
#  617: 'Sushi',
#  618: 'Wasabi',
#  619: 'Wisconsin',
#  620: 'San Francisco',
#  621: 'Papaya',
#  622: 'Eau de Vie',
#  623: 'Grappa',
#  624: 'Scotch',
#  625: 'Jícama',
#  626: 'Pacific Northwest',
#  627: 'Venison',
#  628: 'Pizza',
#  629: 'Virginia',
#  630: 'Goose',
#  631: 'Kirsch',
#  632: 'Quail'}
