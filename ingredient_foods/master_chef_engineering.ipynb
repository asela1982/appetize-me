# %% [markdown]
# ## Data Cleaning

# %%
#Dependencies
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Step 1. Import csv files, convert to df and concatentate them into one file.

# %%
recipe_df1 = pd.read_csv('ScrapeData/csv_recipes/recipe_df1.csv',low_memory=False)
recipe_df2 = pd.read_csv('ScrapeData/csv_recipes/recipe_df2.csv',low_memory=False)
recipe_df3 = pd.read_csv('ScrapeData/csv_recipes/recipe_df3.csv',low_memory=False)
recipe_df4 = pd.read_csv('ScrapeData/csv_recipes/recipe_df4.csv',low_memory=False)
recipe_df5 = pd.read_csv('ScrapeData/csv_recipes/recipe_df5.csv',low_memory=False)

# Add merge all df into one df. 
all_recipes = pd.concat([recipe_df1, recipe_df2,recipe_df3, recipe_df4, recipe_df5],ignore_index=True)

# %%
all_recipes.head()
# Out:
#    Unnamed: 0  bestrating  id  \
# 0         0.0         4.0 NaN
# 1         1.0         4.0 NaN
# 2         2.0         4.0 NaN
# 3         3.0         4.0 NaN
# 4         4.0         4.0 NaN
#
#                                             imagesrc  \
# 0  https://assets.epicurious.com/photos/56df1d8cb...
# 1  https://assets.epicurious.com/photos/5a78b5919...
# 2  https://assets.epicurious.com/photos/5a68f33b3...
# 3  https://assets.epicurious.com/photos/5a9971b01...
# 4  https://assets.epicurious.com/photos/54b71d9a2...
#
#                                          ingredients makeitagainscore  \
# 0  ['2 cups whole-wheat flour', '2 cups all-purpo...              90%
# 1  ['1 Tbsp. crushed red pepper flakes', '1 Tbsp....              91%
# 2  ['1/4 cup extra-virgin olive oil', '12 oz. dry...              67%
# 3  ['1 tablespoon olive oil', '2 garlic cloves, t...              81%
# 4  ['1 1/2 pounds boneless, skinless chicken brea...              96%
#
#                                          preparation  rating  reviews  \
# 0  Put oven rack in middle position and preheat o...     3.5     50.0
# 1  Coarsely grind red pepper flakes, peppercorns,...     3.0     11.0
# 2  Pour oil into cooker insert and select “Sauté....     2.0     15.0
# 3  Preheat oven to 350°F. Heat oil in a large ski...     3.5     26.0
# 4  Place chicken, garlic, bay leaves, allspice, a...     3.5     23.0
#
#                                                 tags  \
# 0  ['Irish', 'Bread', 'Bake', 'Vegetarian', 'Quic...
# 1  ['Pepper', 'Fennel', 'Pork', 'Garlic', 'White ...
# 2  ['Instant Pot', 'Kale', 'Potato', 'Onion', 'Ga...
# 3  ['Side', 'Bake', 'Christmas', 'Easter', 'Thank...
# 4  ['Asian', 'Soup/Stew', 'Chicken', 'Low Carb', ...
#
#                                                title
# 0                                 Irish Brown Bread
# 1                   Slow-Cooked Pork with Chickpeas
# 2                           Instant Pot Caldo Verde
# 3  Parmesan Bread Pudding with Broccoli Rabe and ...
# 4  Brothy Poached Chicken with Mushrooms and Fres...

# %%
# Check for missing rows
all_recipes.count()
# Out:
# Unnamed: 0          4858
# bestrating          6662
# id                  1816
# imagesrc            5016
# ingredients         6674
# makeitagainscore    6662
# preparation         6672
# rating              6662
# reviews             6662
# tags                6646
# title               6673
# dtype: int64

# %%
# Drop 'Unnamed 0:' and 'id 'columns before we dropping rows with empty cells.
all_recipes.drop('Unnamed: 0',axis=1, inplace=True)
all_recipes.drop('id',axis=1, inplace=True)

all_recipes.count()
# Out:
# bestrating          6662
# imagesrc            5016
# ingredients         6674
# makeitagainscore    6662
# preparation         6672
# rating              6662
# reviews             6662
# tags                6646
# title               6673
# dtype: int64

# %%
# Drop empty rows and convert into a new df.
all_clean_recipes = all_recipes.dropna(axis=0, how="any")
all_clean_recipes.count()
# Out:
# bestrating          4990
# imagesrc            4990
# ingredients         4990
# makeitagainscore    4990
# preparation         4990
# rating              4990
# reviews             4990
# tags                4990
# title               4990
# dtype: int64

# %% [markdown]
# ## Step 2. Get all the tags from each recipe to use for UI selection.

# %%
# Getting the tags from the first recipe
all_clean_recipes['tags'].iloc[0]
# Out:
# '[\'Irish\', \'Bread\', \'Bake\', \'Vegetarian\', \'Quick & Easy\', "St. Patrick\'s Day", \'Spring\', \'Gourmet\']'

# %%
# ast - Abstract Syntax Tree - processes trees of the Python abstract syntax grammar.
import ast

# The "ast.literal_eval()" evaluates an expression node or a Unicode
# or Latin-1 encoded string containing a Python literal. 
# The string or node provided may only consist of the following 
# Python literal structures: strings, numbers, tuples, lists, dicts, booleans, and None.
# Returns words that have proper syntax/grammar.
all_tags = []
for index, row in all_clean_recipes.iterrows():
    tags = ast.literal_eval(row["tags"])
    for tag in tags:
        all_tags.append(tag)

# %%
# What the tags look like after using ast 
all_tags[0:8]
# Out:
# ['Irish',
#  'Bread',
#  'Bake',
#  'Vegetarian',
#  'Quick & Easy',
#  "St. Patrick's Day",
#  'Spring',
#  'Gourmet']

# %%
# How many tags from all the recipes?
len(all_tags)
# Out:
# 75836

# %%
# Get unigue tags and remove duplicates. Convert it to a list for indexing. 
unique_tags = list(set(all_tags))
len(unique_tags)
# Out:
# 633

# %%
# Convert the list to a dictionary
tags_dict = {k: v for k, v in enumerate(unique_tags)}
tags_dict
# Out:
# {0: 'Fry',
#  1: 'Wild Rice',
#  2: 'One-Pot Meal',
#  3: 'Kidney Friendly',
#  4: 'Poppy',
#  5: 'Sukkot',
#  6: 'Radicchio',
#  7: 'White Wine',
#  8: 'Japanese',
#  9: 'Instant Pot',
#  10: 'Fat Free',
#  11: 'Portland',
#  12: 'Lamb',
#  13: 'Wok',
#  14: 'Asian',
#  15: 'Argentine',
#  16: 'Low Carb',
#  17: 'House Cocktail',
#  18: 'Marzipan',
#  19: 'Poultry Sausage',
#  20: 'Winter',
#  21: 'Virginia',
#  22: 'Casserole/Gratin',
#  23: 'Apple Juice',
#  24: 'Olive',
#  25: 'Chocolate',
#  26: 'Tuna',
#  27: 'Graduation',
#  28: 'Organic',
#  29: 'Seattle',
#  30: 'Rum',
#  31: 'Central/South American',
#  32: 'Spritzer',
#  33: 'Wasabi',
#  34: 'Edible Gift',
#  35: 'Duck',
#  36: 'Pistachio',
#  37: 'Wedding',
#  38: 'Cottage Cheese',
#  39: 'Cumin',
#  40: 'Middle Eastern',
#  41: 'Slow Cooker',
#  42: 'Thyme',
#  43: 'Pork',
#  44: 'Cuban',
#  45: 'Dairy',
#  46: 'No-Cook',
#  47: 'Bronx',
#  48: 'Rutabaga',
#  49: 'Salmon',
#  50: 'Meat',
#  51: 'Herb',
#  52: 'Pork Rib',
#  53: 'Cocktail',
#  54: 'Quail',
#  55: 'White Chocolate',
#  56: 'Sour Cream',
#  57: 'Engagement Party',
#  58: 'Blender',
#  59: 'Paleo',
#  60: 'Snapper',
#  61: 'South Carolina',
#  62: 'Parsley',
#  63: 'Watercress',
#  64: "Hors D'Oeuvre",
#  65: 'Low Fat',
#  66: 'Raspberry',
#  67: 'No Meat, No Problem',
#  68: 'Diabetes-Friendly',
#  69: 'Avocado',
#  70: 'Calvados',
#  71: 'Potato',
#  72: 'Sauce Secrets',
#  73: 'Pear',
#  74: 'Endive',
#  75: 'Vietnamese',
#  76: 'Sugar Conscious',
#  77: 'Trout',
#  78: 'Brooklyn',
#  79: 'turkey',
#  80: 'Jícama',
#  81: 'Shower',
#  82: 'Pan-Fry',
#  83: 'Bell Pepper',
#  84: 'Persian New Year',
#  85: "Valentine's Day",
#  86: 'Lasagna',
#  87: 'Houston',
#  88: 'Campari',
#  89: 'Couscous',
#  90: 'Oscars',
#  91: '30 Days of Groceries',
#  92: 'Dill',
#  93: 'Nectarine',
#  94: 'Dinner',
#  95: 'Prune',
#  96: 'Peanut Free',
#  97: 'Stuffing/Dressing',
#  98: 'Birthday',
#  99: 'Eau de Vie',
#  100: 'Cook Like a Diner',
#  101: 'Scandinavian',
#  102: 'Thanksgiving',
#  103: 'Buffalo',
#  104: 'Sandwich',
#  105: 'Ice Cream Machine',
#  106: 'Sake',
#  107: 'Orzo',
#  108: 'Tea',
#  109: 'Shallot',
#  110: "St. Patrick's Day",
#  111: 'Watermelon',
#  112: 'Chile',
#  113: 'Tapioca',
#  114: 'Strawberry',
#  115: 'Southern Italian',
#  116: 'Pomegranate Juice',
#  117: 'Pasta',
#  118: 'Veal',
#  119: 'Potluck',
#  120: 'Pork Chop',
#  121: "New Year's Day",
#  122: 'Candy Thermometer',
#  123: 'Pizza',
#  124: 'Gin',
#  125: 'Martini',
#  126: 'Pescatarian',
#  127: 'Banana',
#  128: 'Scallop',
#  129: 'Cardamom',
#  130: 'Chicken',
#  131: 'Oatmeal',
#  132: 'Basque',
#  133: 'Bon App��tit',
#  134: 'Lychee',
#  135: 'Southwestern',
#  136: 'Los Angeles',
#  137: 'Braise',
#  138: 'Hot Drink',
#  139: 'Beef Shank',
#  140: 'Appetizer',
#  141: 'Lunch',
#  142: 'English',
#  143: 'Shavuot',
#  144: 'Tomato',
#  145: 'Sandwich Theory',
#  146: 'Yogurt',
#  147: 'Beef',
#  148: 'Beet',
#  149: 'Broccoli Rabe',
#  150: 'Indonesian',
#  151: 'Picnic',
#  152: 'Brown Rice',
#  153: 'Smoker',
#  154: 'Biscuit',
#  155: 'Dip',
#  156: 'Chive',
#  157: 'Rabbit',
#  158: 'Lettuce',
#  159: 'Honeydew',
#  160: 'Swordfish',
#  161: 'Cognac/Armagnac',
#  162: 'Alcoholic',
#  163: 'Punch',
#  164: 'Buffet',
#  165: 'Washington',
#  166: 'Garlic',
#  167: 'snack week',
#  168: '#CAKEWEEK',
#  169: 'San Francisco',
#  170: 'Sephardic',
#  171: 'Arugula',
#  172: 'Pot Pie',
#  173: 'Eastern European/Russian',
#  174: 'Saffron',
#  175: 'Egg Nog',
#  176: 'Marsala',
#  177: 'Fall',
#  178: 'Bake',
#  179: 'Poker/Game Night',
#  180: 'Squid',
#  181: 'Sage',
#  182: 'Sangria',
#  183: 'Butter',
#  184: 'Tailgating',
#  185: 'Lentil',
#  186: 'Cinnamon',
#  187: 'Milk/Cream',
#  188: 'Phyllo/Puff Pastry Dough',
#  189: 'Quince',
#  190: 'Bean',
#  191: 'Tarragon',
#  192: 'Apple',
#  193: 'Lemon Juice',
#  194: 'Anchovy',
#  195: 'Cherry',
#  196: 'Passover',
#  197: 'Broil',
#  198: 'Broccoli',
#  199: 'Easter',
#  200: 'Zucchini',
#  201: 'Halloween',
#  202: 'Grill',
#  203: 'Mortar and Pestle',
#  204: 'Pumpkin',
#  205: 'Hominy/Cornmeal/Masa',
#  206: 'Cinco de Mayo',
#  207: 'Candy',
#  208: 'Dessert',
#  209: 'Fig',
#  210: 'European',
#  211: 'Low Cholesterol',
#  212: 'Ground Lamb',
#  213: 'Coffee Grinder',
#  214: 'Gouda',
#  215: 'Pepper',
#  216: 'Leafy Green',
#  217: 'No Sugar Added',
#  218: 'Southern',
#  219: 'India',
#  220: 'Salad',
#  221: 'Deep-Fry',
#  222: 'Jalapeño',
#  223: 'Breadcrumbs',
#  224: 'Prosciutto',
#  225: 'Amaretto',
#  226: 'Radish',
#  227: 'Spring',
#  228: 'Northern Italian',
#  229: 'Tequila',
#  230: 'Beer',
#  231: 'Wisconsin',
#  232: 'Stir-Fry',
#  233: 'Poultry',
#  234: 'Low Cal',
#  235: 'Shellfish',
#  236: 'Sherry',
#  237: 'Kwanzaa',
#  238: 'Southeast Asian',
#  239: 'Texas',
#  240: 'Cream Cheese',
#  241: 'Mozzarella',
#  242: 'Orange Juice',
#  243: 'Labor Day',
#  244: 'Italian American',
#  245: 'Mint',
#  246: 'Goat Cheese',
#  247: 'Sauté',
#  248: 'Anniversary',
#  249: 'Guava',
#  250: 'Cashew',
#  251: 'Australian/New Zealand',
#  252: 'Dairy Free',
#  253: 'Mango',
#  254: 'Marrakech',
#  255: 'Pasadena',
#  256: 'Szechuan/Hunan',
#  257: 'Berry',
#  258: 'Semolina',
#  259: 'Whole Wheat',
#  260: 'Triple Sec',
#  261: 'Dinner 1-2-3',
#  262: 'Kid-Friendly',
#  263: 'German',
#  264: 'Poblano',
#  265: 'Basil',
#  266: 'Colorado',
#  267: 'Ricotta',
#  268: 'Ashkenazi',
#  269: 'Thai',
#  270: 'Leek',
#  271: 'Apricot',
#  272: 'Sushi',
#  273: '3-Ingredient Recipes',
#  274: 'Gourmet',
#  275: 'Lime Juice',
#  276: 'Mediterranean',
#  277: 'Rosemary',
#  278: 'Hanukkah',
#  279: 'Crab',
#  280: 'Coconut',
#  281: 'Turnip',
#  282: 'Hazelnut',
#  283: 'Red Wine',
#  284: 'Bass',
#  285: 'Marscarpone',
#  286: 'Papaya',
#  287: 'Michigan',
#  288: 'Honey',
#  289: 'Pasta Maker',
#  290: 'Pacific Northwest',
#  291: 'Rice',
#  292: 'Goose',
#  293: 'Pennsylvania',
#  294: 'Pernod',
#  295: 'Scotch',
#  296: 'Bitters',
#  297: 'Green Onion/Scallion',
#  298: 'Champagne',
#  299: 'Paprika',
#  300: 'Cantaloupe',
#  301: 'Grape',
#  302: 'Marshmallow',
#  303: 'Nuevo Latino',
#  304: 'Healthy',
#  305: 'Seed',
#  306: 'Kosher for Passover',
#  307: 'Melon',
#  308: 'Molasses',
#  309: 'Korean',
#  310: 'Lima Bean',
#  311: 'Salad Dressing',
#  312: 'Christmas',
#  313: "Mother's Day",
#  314: 'Food Processor',
#  315: 'Mayonnaise',
#  316: 'Butternut Squash',
#  317: 'Tamarind',
#  318: 'Pittsburgh',
#  319: "Father's Day",
#  320: 'Condiment',
#  321: 'Cookie',
#  322: 'Massachusetts',
#  323: 'Bulgur',
#  324: 'Dried Fruit',
#  325: 'Fourth of July',
#  326: 'Lamb Chop',
#  327: 'Oyster',
#  328: 'Pineapple',
#  329: 'Quiche',
#  330: 'Tree Nut Free',
#  331: 'Chinese',
#  332: 'Lobster',
#  333: 'Barley',
#  334: 'Spice',
#  335: 'Flaming Hot Summer',
#  336: 'Pork Tenderloin',
#  337: 'Fennel',
#  338: 'Beef Tenderloin',
#  339: 'New Mexico',
#  340: 'Ramekin',
#  341: 'Port',
#  342: 'Jam or Jelly',
#  343: 'New Orleans',
#  344: 'Kirsch',
#  345: 'Coriander',
#  346: 'Citrus',
#  347: 'Persimmon',
#  348: 'Parsnip',
#  349: 'Vinegar',
#  350: 'High Fiber',
#  351: 'Waffle',
#  352: 'Cranberry',
#  353: 'French',
#  354: 'Chickpea',
#  355: 'Mixer',
#  356: 'Chill',
#  357: 'Brazilian',
#  358: 'Chili',
#  359: 'Cornmeal',
#  360: 'New England',
#  361: 'Vegetarian',
#  362: 'Diwali',
#  363: 'Self',
#  364: 'Mardi Gras',
#  365: 'Georgia',
#  366: 'Muffin',
#  367: 'Liqueur',
#  368: 'Vegetable',
#  369: 'Mustard',
#  370: 'Low/No Sugar',
#  371: 'Peanut',
#  372: 'Midwestern',
#  373: 'Parade',
#  374: 'Chestnut',
#  375: 'Weelicious',
#  376: 'Brownie',
#  377: 'Quinoa',
#  378: 'Frankenrecipe',
#  379: 'Meatball',
#  380: 'Pastry',
#  381: 'Clove',
#  382: 'Date',
#  383: 'Feta',
#  384: 'Ginger',
#  385: 'Walnut',
#  386: 'Asian Pear',
#  387: 'Raisin',
#  388: 'Granola',
#  389: 'Cilantro',
#  390: 'Maple Syrup',
#  391: 'Green Bean',
#  392: 'Takeout at Home',
#  393: 'Frittata',
#  394: 'Sausage',
#  395: 'Dark Chocolate',
#  396: 'Tex-Mex',
#  397: 'Brandy',
#  398: 'Blue Cheese',
#  399: 'Mexico',
#  400: 'Cheese Week',
#  401: 'Squash',
#  402: 'Steak',
#  403: 'Brisket',
#  404: 'Kumquat',
#  405: 'Mushroom',
#  406: 'Whiskey',
#  407: 'Nut',
#  408: 'Tree Nut',
#  409: 'Legume',
#  410: 'Parmesan',
#  411: 'Canadian',
#  412: 'Small Plates',
#  413: 'Spinach',
#  414: 'Greek',
#  415: 'Margarita',
#  416: 'Lime',
#  417: 'Aperitif',
#  418: 'Italian',
#  419: 'Poach',
#  420: 'Nutmeg',
#  421: 'Venison',
#  422: 'Rye',
#  423: 'Kosher',
#  424: 'Tangerine',
#  425: 'Clam',
#  426: 'Artichoke',
#  427: 'Passion Fruit',
#  428: 'Vegan',
#  429: 'Spirit',
#  430: 'Sardine',
#  431: 'Cocktail Party',
#  432: 'Freeze/Chill',
#  433: 'Jerusalem Artichoke',
#  434: 'British',
#  435: 'Wheat/Gluten-Free',
#  436: 'Brie',
#  437: 'Entertaining',
#  438: 'Irish',
#  439: 'Brussels Sprout',
#  440: 'Bon Appétit',
#  441: 'Double Boiler',
#  442: 'Latin American',
#  443: 'Currant',
#  444: 'Turkish',
#  445: 'Ham',
#  446: 'Vodka',
#  447: 'Brine',
#  448: 'Spanish/Portuguese',
#  449: 'Caraway',
#  450: 'Escarole',
#  451: 'Sesame Oil',
#  452: 'Smoothie',
#  453: 'Bacon',
#  454: 'Curry',
#  455: 'Okra',
#  456: 'Mexican',
#  457: 'Pea',
#  458: 'Pancake',
#  459: 'Steam',
#  460: 'Central American/Caribbean',
#  461: 'Mustard Greens',
#  462: 'Fruit',
#  463: 'HarperCollins',
#  464: 'South American',
#  465: '#cook90',
#  466: 'Bok Choy',
#  467: 'Bread',
#  468: 'Grill/Barbecue',
#  469: 'Israeli',
#  470: 'Orange',
#  471: 'Blackberry',
#  472: 'Backyard BBQ',
#  473: 'Sparkling Wine',
#  474: 'Fortified Wine',
#  475: 'Side',
#  476: 'Condiment/Spread',
#  477: 'Moroccan',
#  478: 'Taco',
#  479: 'Carrot',
#  480: 'Non-Alcoholic',
#  481: 'Party',
#  482: 'Raw',
#  483: 'Peach',
#  484: 'Lunar New Year',
#  485: 'Pie',
#  486: 'Drink',
#  487: 'South Asian',
#  488: 'New Jersey',
#  489: 'Fruit Juice',
#  490: 'Wine',
#  491: 'Rhubarb',
#  492: 'New York',
#  493: 'Yonkers',
#  494: 'Pecan',
#  495: 'Collard Greens',
#  496: 'Iced Coffee',
#  497: 'Roast',
#  498: 'Horseradish',
#  499: 'Marinate',
#  500: 'Dallas',
#  501: 'Plantain',
#  502: 'Christmas Eve',
#  503: 'Onion',
#  504: 'Anise',
#  505: 'Noodle',
#  506: 'Butterscotch/Caramel',
#  507: 'Cheddar',
#  508: 'Grapefruit',
#  509: 'Kiwi',
#  510: 'Morocco',
#  511: 'Kale',
#  512: 'Seafood',
#  513: 'Sesame',
#  514: '22-Minute Meals',
#  515: 'Pine Nut',
#  516: 'Gluten-Free and Fresh',
#  517: 'Cookies',
#  518: 'Oktoberfest',
#  519: 'Summer',
#  520: 'Celery',
#  521: 'Arizona',
#  522: 'Frozen Dessert',
#  523: 'Pomegranate',
#  524: 'Tart',
#  525: 'Indian',
#  526: 'Cabbage',
#  527: 'Mandoline',
#  528: 'Jewish',
#  529: 'Sourdough',
#  530: 'Simmer',
#  531: 'Cake',
#  532: 'Rosh Hashanah/Yom Kippur',
#  533: 'Cauliflower',
#  534: 'Mussel',
#  535: 'Sweet Potato/Yam',
#  536: 'Oregano',
#  537: 'Plum',
#  538: 'Grand Marnier',
#  539: 'Egg',
#  540: 'Quick and Healthy',
#  541: 'Chile Pepper',
#  542: 'Fish',
#  543: 'Boil',
#  544: 'Cajun/Creole',
#  545: 'Tropical Fruit',
#  546: 'Californian',
#  547: 'Breakfast',
#  548: 'Macadamia Nut',
#  549: 'Frangelico',
#  550: 'Pressure Cooker',
#  551: 'Greece',
#  552: 'Shrimp',
#  553: 'Halibut',
#  554: 'Swiss Cheese',
#  555: 'Blueberry',
#  556: 'Alabama',
#  557: 'Vanilla',
#  558: 'Indiana',
#  559: 'snack',
#  560: 'Rosé',
#  561: 'Ethiopian',
#  562: 'Asparagus',
#  563: 'Chard',
#  564: 'Oat',
#  565: 'Healdsburg',
#  566: 'Family Reunion',
#  567: 'Soy Sauce',
#  568: 'Lemon',
#  569: 'Drinks',
#  570: 'Monterey Jack',
#  571: 'Grappa',
#  572: 'Back to School',
#  573: 'Capers',
#  574: 'Buttermilk',
#  575: 'Sauce',
#  576: 'Soup/Stew',
#  577: 'Hot Pepper',
#  578: 'Cheese',
#  579: 'Corn',
#  580: 'Hamburger',
#  581: 'American',
#  582: 'Tortillas',
#  583: 'Purim',
#  584: 'Cod',
#  585: 'cookbooks',
#  586: 'French Provençal',
#  587: 'Atlanta',
#  588: "New Year's Eve",
#  589: 'Game',
#  590: 'African',
#  591: 'Yellow Squash',
#  592: 'Bourbon',
#  593: 'Stew',
#  594: 'Cast Iron',
#  595: 'Low Sodium',
#  596: 'Bastille Day',
#  597: 'Canada',
#  598: 'Tilapia',
#  599: 'Soy Free',
#  600: 'Eggplant',
#  601: 'Ramadan',
#  602: 'Kentucky Derby',
#  603: 'Peanut Butter',
#  604: 'Almond',
#  605: 'Rack of Lamb',
#  606: 'Ohio',
#  607: 'Grains',
#  608: 'Lamb Shank',
#  609: 'California',
#  610: 'Meatloaf',
#  611: 'Central Asian',
#  612: 'Tofu',
#  613: 'Cucumber',
#  614: 'Vermouth',
#  615: 'Coffee',
#  616: 'Advance Prep Required',
#  617: 'Brunch',
#  618: 'Sugar Snap Pea',
#  619: 'Skewer',
#  620: 'Tomatillo',
#  621: 'Root Vegetable',
#  622: 'Quick & Easy',
#  623: 'Beef Rib',
#  624: 'Ground Beef',
#  625: 'Oregon',
#  626: 'Microwave',
#  627: 'Fontina',
#  628: 'Lemongrass',
#  629: 'Soy',
#  630: 'Macaroni and Cheese',
#  631: 'Freezer Food',
#  632: 'Super Bowl'}

# %% [markdown]
# ## Summary for recipe tags.
# ---
# - There were 75,836 tags for all the recipes.
# - These were reduced to unique 633 tags (0.8%).
# - However, some tags can need to be removed. like, "Kidney Friendly", "Bon App��tit","#CAKEWEEK".

# %% [markdown]
# ## Step 3.  Get all the ingredients from each recipe to use for UI selection.

# %%
# Getting the ingredients from the first recipe
all_clean_recipes['ingredients'].iloc[0]
# Out:
# "['2 cups whole-wheat flour', '2 cups all-purpose flour plus additional for kneading', '1/2 cup toasted wheat germ', '2 teaspoons salt', '2 teaspoons sugar', '1 teaspoon baking soda', '1/2 teaspoon cream of tartar', '1 stick (1/2 cup) cold unsalted butter, cut into 1/2-inch cubes', '2 cups well-shaken buttermilk']"

# %%
# Each character and letter is indexed. 
len(all_clean_recipes['ingredients'].iloc[0])
# Out:
# 314

# %% [markdown]
# ### We need to separate out each step and then separate each word in each step to get all the unique ingredients for all the recipes.

# %%
# Using ast we can separate out the indvidual steps.
all_ingredients = []
for index, row in all_clean_recipes.iterrows():
    tags = ast.literal_eval(row["ingredients"])
    for tag in tags:
        all_ingredients.append(tag)

# %%
# The first 8 ingredients
all_ingredients[0:9]
# Out:
# ['2 cups whole-wheat flour',
#  '2 cups all-purpose flour plus additional for kneading',
#  '1/2 cup toasted wheat germ',
#  '2 teaspoons salt',
#  '2 teaspoons sugar',
#  '1 teaspoon baking soda',
#  '1/2 teaspoon cream of tartar',
#  '1 stick (1/2 cup) cold unsalted butter, cut into 1/2-inch cubes',
#  '2 cups well-shaken buttermilk']

# %%
# The number of steps in all the ingridients
len(all_ingredients)
# Out:
# 56256

# %%
# Remove characters and numbers in the ingredients using regular expression (re) module.
import re
ingredients = []
pattern = "([^\d\\.\\,\\\;\\*\\]\\[\\%\\½\\<\\>\\:\\°\\?\\�\\}\\{\)\(\"\/\s]+)"
for ingredient in set(all_ingredients):
    p = re.compile(pattern)
    result = p.findall(ingredient) 
    ingredients.append(result)

# %%
# The first 8 ingredients
ingredients[0:9]
# Out:
# [['Garnish', 'pomegranate', 'seeds', 'from', 'pomegranate'],
#  ['tablespoons', 'dried', 'chanterelle', 'or', 'shiitake', 'mushrooms'],
#  ['small', 'pork', 'tenderloins', 'to', 'pounds', 'total'],
#  ['cups', 'or', 'more', 'flour'],
#  ['pound',
#   'boneless',
#   'skinless',
#   'chicken',
#   'breasts',
#   'cut',
#   'into',
#   '-inch',
#   'strips'],
#  ['cup', 'slivered', 'almonds'],
#  ['Peanut', 'oil', 'for', 'frying'],
#  ['mango', 'cut', 'into', 'thin', 'strips'],
#  ['cup',
#   'chopped',
#   'fresh',
#   'basil',
#   'plus',
#   'whole',
#   'large',
#   'basil',
#   'leaves']]

# %%
# So we have a list of words and lists. 
# We need to iterated through the lists to get single words in one list.
separate_ingridents = []
for food in ingredients:
    for item in food:
        separate_ingridents.append(item)

# %%
# The first 8 ingredients
separate_ingridents[0:9]
# Out:
# ['Garnish',
#  'pomegranate',
#  'seeds',
#  'from',
#  'pomegranate',
#  'tablespoons',
#  'dried',
#  'chanterelle',
#  'or']

# %%
# How many ingredients
len(separate_ingridents)
# Out:
# 182402

# %%
# Get the unique ingredients and put them in a list. 
unique_ingredients = list(set(separate_ingridents))

# %%
# The first 8 ingredients
unique_ingredients[0:9]
# Out:
# ['rim',
#  'quick-rising',
#  'High-speed',
#  'Popovers',
#  'delicata',
#  'Porcini',
#  'acini',
#  'depending',
#  'thickly']

# %%
# How many ingredients
len(unique_ingredients)
# Out:
# 5592

# %% [markdown]
# ### We reduced out 182,402 words in the ingridients to  5,592. This is still a lot.  Using a json food file that has food labels we can add these food labels to stopwords and use the Natural Language Tool Kit (nltk) to remove these words from our list.

# %%
import json
import nltk 
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
food_data = json.load(open('validfood.json'))
food_data
# Out:
# {'hints': [{'food': {'label': 'Lima beans, immature seeds, raw',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_11031'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Cup',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup'},
#     {'label': 'Salt spoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_salt_spoon'},
#     {'label': 'Quart',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_quart'},
#     {'label': 'Teaspoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_teaspoon'},
#     {'label': 'Smidgen',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_smidgen'},
#     {'label': 'Drop',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_drop'},
#     {'label': 'Gallon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gallon'},
#     {'label': 'Dash',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_dash'},
#     {'label': 'Handful',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_handful'},
#     {'label': 'Scoop',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_scoop'},
#     {'label': 'Bowl',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bowl'},
#     {'label': 'Cubic inch',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cubic_inch'},
#     {'label': 'Pinch',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pinch'},
#     {'label': 'Liter',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_liter'},
#     {'label': 'Milliliter',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter'},
#     {'label': 'Tablespoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon'},
#     {'label': 'Fluid ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_fluid_ounce'},
#     {'label': 'Bottle',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bottle'},
#     {'label': 'Tad',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tad'},
#     {'label': 'Pint',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pint'},
#     {'label': 'Dessert spoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_dessert_spoon'}]},
#   {'food': {'label': 'Lima beans, large, mature seeds, raw',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_16071'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Cup',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup'},
#     {'label': 'Tablespoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon'},
#     {'label': 'Salt spoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_salt_spoon'},
#     {'label': 'Quart',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_quart'},
#     {'label': 'Teaspoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_teaspoon'},
#     {'label': 'Smidgen',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_smidgen'},
#     {'label': 'Drop',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_drop'},
#     {'label': 'Gallon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gallon'},
#     {'label': 'Dash',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_dash'},
#     {'label': 'Handful',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_handful'},
#     {'label': 'Scoop',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_scoop'},
#     {'label': 'Bowl',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bowl'},
#     {'label': 'Cubic inch',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cubic_inch'},
#     {'label': 'Pinch',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pinch'},
#     {'label': 'Liter',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_liter'},
#     {'label': 'Milliliter',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter'},
#     {'label': 'Fluid ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_fluid_ounce'},
#     {'label': 'Bottle',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bottle'},
#     {'label': 'Tad',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tad'},
#     {'label': 'Pint',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pint'},
#     {'label': 'Dessert spoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_dessert_spoon'}]},
#   {'food': {'label': 'Lima beans, large, mature seeds, canned',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_16073'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Can',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_can'},
#     {'label': 'Cup',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup'},
#     {'label': 'Salt spoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_salt_spoon'},
#     {'label': 'Quart',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_quart'},
#     {'label': 'Teaspoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_teaspoon'},
#     {'label': 'Smidgen',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_smidgen'},
#     {'label': 'Drop',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_drop'},
#     {'label': 'Gallon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gallon'},
#     {'label': 'Dash',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_dash'},
#     {'label': 'Handful',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_handful'},
#     {'label': 'Scoop',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_scoop'},
#     {'label': 'Bowl',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bowl'},
#     {'label': 'Cubic inch',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cubic_inch'},
#     {'label': 'Pinch',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pinch'},
#     {'label': 'Liter',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_liter'},
#     {'label': 'Milliliter',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter'},
#     {'label': 'Tablespoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon'},
#     {'label': 'Fluid ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_fluid_ounce'},
#     {'label': 'Bottle',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bottle'},
#     {'label': 'Tad',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tad'},
#     {'label': 'Pint',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pint'},
#     {'label': 'Dessert spoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_dessert_spoon'}]},
#   {'food': {'label': 'LIMA BEAN FLOUR',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_USDABR_45322004'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'}]},
#   {'food': {'label': 'Christmas Lima Bean Salad',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Christmas_Lima_Bean_Salad'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'Fresh Lima Bean Gratins',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Fresh_Lima_Bean_Gratins'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'Hearty Lima Bean Bake',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Hearty_Lima_Bean_Bake'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'Lima Bean Medley',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Lima_Bean_Medley'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'Lima Bean Soup',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Lima_Bean_Soup'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'Lima Bean Spread',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Lima_Bean_Spread'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'Luscious Lima Bean Soup',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Luscious_Lima_Bean_Soup'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'SOUP MIX, LIMA BEAN WITH BARLEY',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_USDABR_45232345'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'}]},
#   {'food': {'label': 'Chicken, Corn and Lima Bean Stew',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Chicken_Corn_and_Lima_Bean_Stew'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'Lima Bean Spread with Cumin & Herbs',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#_generic_meal_Lima_Bean_Spread_with_Cumin_Herbs'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Whole',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_unit'}]},
#   {'food': {'label': 'Kedem Homestyle Lima Bean With Barley Soup Mix',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_EWG_073490124792_KedemHomestyleLimaBeanWithBarleySoupMix'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'},
#     {'label': 'Cup',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cup'},
#     {'label': 'Serving',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_serving'},
#     {'label': 'Package',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_package'},
#     {'label': 'Salt spoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_salt_spoon'},
#     {'label': 'Quart',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_quart'},
#     {'label': 'Teaspoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_teaspoon'},
#     {'label': 'Smidgen',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_smidgen'},
#     {'label': 'Drop',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_drop'},
#     {'label': 'Gallon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gallon'},
#     {'label': 'Dash',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_dash'},
#     {'label': 'Handful',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_handful'},
#     {'label': 'Scoop',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_scoop'},
#     {'label': 'Bowl',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bowl'},
#     {'label': 'Cubic inch',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_cubic_inch'},
#     {'label': 'Pinch',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pinch'},
#     {'label': 'Liter',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_liter'},
#     {'label': 'Milliliter',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_milliliter'},
#     {'label': 'Tablespoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tablespoon'},
#     {'label': 'Fluid ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_fluid_ounce'},
#     {'label': 'Bottle',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_bottle'},
#     {'label': 'Tad',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_tad'},
#     {'label': 'Pint',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pint'},
#     {'label': 'Dessert spoon',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_dessert_spoon'}]},
#   {'food': {'label': 'Manischewitz Lima Bean with Barley Soup Mix',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_IM_8714bbb0-dfd1-11e5-a6ef-005056b61af0'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'}]},
#   {'food': {'label': 'Lima Beans',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_FF_Ponderosa_51091_Lima_Beans'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'}]},
#   {'food': {'label': 'LIMA BEANS',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_USDABR_45019318'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'}]},
#   {'food': {'label': 'LIMA BEANS',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_USDABR_45059125'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'}]},
#   {'food': {'label': 'LIMA BEANS',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_USDABR_45085745'},
#    'measures': [{'label': 'Pound',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_pound'},
#     {'label': 'Kilogram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_kilogram'},
#     {'label': 'Ounce',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_ounce'},
#     {'label': 'Gram',
#      'uri': 'http://www.edamam.com/ontologies/edamam.owl#Measure_gram'}]}],
#  'numPages': 25,
#  'page': 0,
#  'parsed': [{'food': {'label': 'Lima beans, immature seeds, raw',
#     'uri': 'http://www.edamam.com/ontologies/edamam.owl#Food_11031'}}],
#  'text': 'lima bean'}

# %%
# Get the food label from the json file and add them to a list
labels = []
for i in range(len(food_data["hints"][0]["measures"])):
    label = food_data["hints"][0]["measures"][i]["label"]
    labels.append(label.lower())

# %%
labels
# Out:
# ['pound',
#  'kilogram',
#  'ounce',
#  'gram',
#  'cup',
#  'salt spoon',
#  'quart',
#  'teaspoon',
#  'smidgen',
#  'drop',
#  'gallon',
#  'dash',
#  'handful',
#  'scoop',
#  'bowl',
#  'cubic inch',
#  'pinch',
#  'liter',
#  'milliliter',
#  'tablespoon',
#  'fluid ounce',
#  'bottle',
#  'tad',
#  'pint',
#  'dessert spoon']

# %%
# Add the food labels to the stopwords
stopwords = nltk.corpus.stopwords.words('english')
for label in labels:
    stopwords.append(label)

# %%
# print the stopwords to make sure our words are there. 
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 'pound', 'kilogram', 'ounce', 'gram', 'cup', 'salt spoon', 'quart', 'teaspoon', 'smidgen', 'drop', 'gallon', 'dash', 'handful', 'scoop', 'bowl', 'cubic inch', 'pinch', 'liter', 'milliliter', 'tablespoon', 'fluid ounce', 'bottle', 'tad', 'pint', 'dessert spoon']

# %%
# Remove stopword from the ingridients 

filtered_foods = []
for food in unique_ingredients:
    if food not in stopwords:
        filtered_foods.append(food)

# %%
# Get the first 8 foods
print(filtered_foods)
# Out:
# ['rim', 'quick-rising', 'High-speed', 'Popovers', 'delicata', 'Porcini', 'acini', 'depending', 'thickly', 'Pattypan', 'heated', 'kirsch', 'Asian', 'k', 'speck', 'fluke', 'three', 'keeping', 'Pecans', 'prime', 'oblong', 'sheep', 'annatto', 'shiny', 'Test', 'chicharrón', 'core', 'fully', 'lepicerie', 'matchstick', 'vinaigrette', 'seasoning', 'Herb', 'one-cup', 'gutted', 'pickled', 'PHILADELPHIA', 'citrus-cranberry', 'flax', 'tomatoes', 'young', '¼', 'katsuobushi', 'Point', 'attachment', 'Chihuahua', 'walnuts', 'single-serve', 'Sautéed', 'bell-shaped', 'sauté', 'Sierra', 'crusts', 'oxtail', 'Mix', 'Maltaise', 'per', 'snapped', 'quills', 'Choy', 'framboise', 'eyes', 'peel', 'zest', 'uniform', 'pita', 'liverwurst', 'juniper', 'Garlic', 'feta', 'fry', 'Baby', 'plump', 'standing', 'poultry', 'Semi-pearled', 'tissue', 'applejack', 'Few', 'multigrain', 'omega-', 'Nocello', 'coast', 'meatloaf', '-g', 'tablespoons', 'sectioned', 'damson', 'Simple', 'Tangy', 'complete', 'Abruzzo', 'caciocavallo', 'hearty', 'sheet', 'boiled', 'V-', 'chèvre', 'cookies', 'shaping', 'oysters', 'stuffed', 'fitting', 'Tabil', 'torch', 'stone', 'spicy', 'mulato', 'kohlrabi', 'rounds', 'Côtes', 'pequin', "Grey's", 'cottage', 'orzo', 'chunky', 'trimming', 'kochujang', 'Perugina', 'thighs', 'Gravy', 'doughnuts', 'sweetener', 'candied-orange', 'kiwifruit', 'cream', 'ghee', 'pastry', 'rims', 'nuoc', 'navel', 'You', 'pods', 'page', 'Sprinkles', 'chipotles', 'Coarse', 'slim', 'half', 'figs', 'extra-bittersweet', 'tender-roasted', 'Peppers', 'overly', 'Modelo', 'Hong', 'scallops', 'atroom', 'coiled', 'squeezing', 'ruby-red', 'cinnamon-raisin', 'truffle-infused', 'Peas', 'haloumi', 'stir-fry', "Melissa's", 'diced', 'Wafer', 'grainy', 'straining', 'matter', 'gouda', 'shiro', 'tostadas', 'somewhat', 'minutes', 'V-shaped', 'sriracha', 'Bibimbap', 'shapes', 'rich', 'papas', 'Parsnip', 'Vinegar', 'Cranberry', 'analog', 'Vegetables', 'head', 'ale', 'extracted', 'cèpe', 'tbsp', 'seltzer', 'Maine', 'sautéing', 'maple', 'yield', 'branzino', 'according', 'champagne', 'white-skinned', 'Cilantro', 'decorations', 'Cipriani', "Za'atar", 'hamachi', 'unpeeled', 'Fine', 'V-rack', 'purpose', 'Emmentaler', 'applewood', 'cluster', 'husked', 'Transfer', 'crunchy', 'running', 'aniseed', 'narrowing', 'lard', 'radicchio', 'multi-grain', 'extra-bitter', 'couscous', 'Extra', 'cocktail', 'rosé', 'heavy-bottomed', 'flakes', 'kabocha', 'Gold', 'San', 'Baharat', "Junior's", 'The', 'Spy', 'two', 'pastina', 'Bread', 'Eggs', 'épices', 'round', "cow's", 'cognac', 'fiery', 'ballpark', 'Iron', 'Mincemeat', 'Eastern', 'onions', 'caviar', 'visible', 'Fresh', 'Velveeta', 'chowder', 'aka', 'pat', 'doublepeeled', 'terrine', 'batons', 'farm-fresh', 'Generously', 'new', 'grinder', 'Resealable', 'iceberg', 'find', 'Prepared', 'herbed', 'crostini', 'recommended', 'whatever', 'black-truffle', 'commercial', 'Thighs', 'Stoli', 'flank', 'stone-ground', 'appropriate', 'tangy', 'Pan', '-mg', 'Asparagus', '-strips', 'crusty', 'mini-marshmallows', 'refried', 'maple-flavored', 'Laughing', 'luke', 'endive', 'ranging', 'Brain-Boosting', 'rolled', '-bone', 'Water', 'King', 'bottled', 'boiler', 'rose', 'Canada', 'toasted', 'hamburger', 'Thick', 'go', 'without', 'Coating', 'Russian', 'Mandarine', 'scrubbed', 'no-cook', 'Maple-Caramel', 'Candied', 'sodium', 'Up', 'deep-frying', 'full-fat', 'barbecue', 'Oil', 'jarred', 'Calabrian', 'fluted', 'carrots', 'premium', 'jaggery', 'butterscotch', 'Rani', 'tostada', 'bottoms', 'Dover', 'Shaoxing', 'basmati', 'forming', 'tight', 'filets', 'Chile-Thyme', 'Kalamata-style', 'Spinach-Porcini', 'white-truffle', 'leafy', 'cooking', 'spring', 'oiling', 'Whip', 'La', 'bow', 'crystals', 'squashes', 'de', 'pressed', 'Picholine', 'pink-skinned', 'POM', 'loosely', 'rhubarb', 'flavored', 'dowel', 'Roquefort', 'groats', 'teacups', 'mochiko', 'Broth', 'Rinse', 'Aji', 'room-temperature', 'gallons', 'quick-cooking', 'kahlúa', 'Cilantro-Lime', 'cardamom', 'turbinado', 'Chinese-style', 'whole-milk', 'tank',  ...

# %%
# How many did we get?
len(filtered_foods)
# Out:
# 5476

# %%
# Read in the some common foods csv to match the foods in our list. These could've been added
# to the stopwords are we could do this before the stopwords. 
foods_df = pd.read_csv('foodb_2017_06_29_csv/foods.csv',encoding='latin-1', low_memory=False)

# %%
foods_df.head()
# Out:
#    id            name                 name_scientific  \
# 0   1        Angelica                Angelica keiskei
# 1   2   Savoy cabbage  Brassica oleracea var. sabauda
# 2   3   Silver linden                  Tilia argentea
# 3   4            Kiwi             Actinidia chinensis
# 4   5  Allium (Onion)                          Allium
#
#                                          description   itis_id  \
# 0  Angelica is a genus of about 60 species of tal...       NaN
# 1  Savoy cabbage (Brassica oleracea convar. capit...       NaN
# 2  Tilia tomentosa (Silver Lime in the UK and Sil...       NaN
# 3  The kiwifruit, often shortened to kiwi in many...  506775.0
# 4  Allium haematochiton is a species of wild onio...   42634.0
#
#            wikipedia_id wikipedia_id.1 picture_content_type  \
# 0              Angelica          1.jpg           image/jpeg
# 1         Savoy cabbage          2.jpg           image/jpeg
# 2       Tilia tomentosa          3.jpg           image/jpeg
# 3             Kiwifruit          4.jpg           image/jpeg
# 4  Allium haematochiton          5.jpg           image/jpeg
#
#    picture_file_size       picture_updated_at       ...        \
# 0           111325.0  2012-04-20 09:29:57 UTC       ...
# 1           155178.0  2012-04-20 09:39:54 UTC       ...
# 2            56367.0  2012-04-20 09:41:25 UTC       ...
# 3           110661.0  2012-04-20 09:32:21 UTC       ...
# 4           341911.0  2012-04-20 09:37:44 UTC       ...
#
#              food_subgroup food_type               created_at  \
# 0                    Herbs    Type 1  2011-02-09 00:37:14 UTC
# 1                 Cabbages    Type 1  2011-02-09 00:37:15 UTC
# 2                    Herbs    Type 1  2011-02-09 00:37:15 UTC
# 3          Tropical fruits    Type 1  2011-02-09 00:37:15 UTC
# 4  Onion-family vegetables    Type 1  2011-02-09 00:37:15 UTC
#
#                 updated_at creator_id updater_id  export_to_afcdb  category  \
# 0  2017-06-27 17:13:48 UTC        NaN        2.0            False  specific
# 1  2017-03-20 21:26:22 UTC        NaN        NaN            False  specific
# 2  2015-10-02 21:24:39 UTC        NaN        NaN            False  specific
# 3  2017-03-20 21:26:22 UTC        NaN        NaN            False  specific
# 4  2017-03-20 21:26:22 UTC        NaN        NaN            False  specific
#
#    ncbi_taxonomy_id export_to_foodb
# 0          357850.0            True
# 1         1216010.0            True
# 2               NaN            True
# 3            3625.0            True
# 4            4678.0            True
#
# [5 rows x 22 columns]

# %%
# Convert the food "name" column to a list
foods = foods_df['name'].tolist()
print(foods)
# Out:
# ['Angelica', 'Savoy cabbage', 'Silver linden', 'Kiwi', 'Allium (Onion)', 'Garden onion', 'Leek', 'Garlic', 'Chives', 'Lemon verbena', 'Cashew nut', 'Pineapple', 'Dill', 'Custard apple', 'Wild celery', 'Peanut', 'Burdock', 'Horseradish', 'Tarragon', 'Mugwort', 'Asparagus', 'Oat', 'Star fruit', 'Brazil nut', 'Common beet', 'Borage', 'Chinese mustard', 'Swede', 'Rape', 'Common cabbage', 'Cauliflower', 'Brussel sprouts', 'Kohlrabi', 'Broccoli', 'Chinese cabbage', 'Turnip', 'Pigeon pea', 'Tea', 'Capers', 'Pepper (C. annuum)', 'Papaya', 'Safflower', 'Caraway', 'Pecan nut', 'Chestnut', 'Roman camomile', 'Chickpea', 'Endive', 'Chicory', 'Chinese cinnamon', 'Ceylon cinnamon', 'Watermelon', 'Lime', 'Lemon', 'Pummelo', 'Mandarin orange (Clementine, Tangerine)', 'Sweet orange', 'Coffee', 'Arabica coffee', 'Robusta coffee', 'Coriander', 'Common hazelnut', 'Saffron', 'Muskmelon', 'Cucumber', 'Cucurbita (Gourd)', 'Cumin', 'Turmeric', 'Quince', 'Lemon grass', 'Globe artichoke', 'Wild carrot', 'Japanese persimmon', 'Cardamom', 'Black crowberry', 'Loquat', 'Rocket salad (ssp.)', 'Wax apple', 'Common buckwheat', 'Tartary buckwheat', 'Fig', 'Fennel', 'Strawberry', 'Black huckleberry', 'Soy bean', 'Sunflower', 'Sea-buckthornberry', 'Barley', 'Hyssop', 'Star anise', 'Swamp cabbage', 'Sweet potato', 'Black walnut', 'Common walnut', 'Lettuce', 'Grass pea', 'Sweet bay', 'Lentils', 'Garden cress', 'Lovage', 'Flaxseed', 'Mexican oregano', 'Lichee', 'Lupine', 'Apple', 'Mango', 'German camomile', 'Lemon balm', 'Mentha (Mint)', 'Orange mint', 'Cornmint', 'Spearmint', 'Peppermint', 'Medlar', 'Bitter gourd', 'Mulberry', 'Black mulberry', 'Nutmeg', 'Sweet basil', 'Evening primrose', 'Olive', 'Sweet marjoram', 'Pot marjoram', 'Common oregano', 'Rice', 'Millet', 'Poppy', 'Passion fruit', 'Parsnip', 'Avocado', 'Parsley', 'Scarlet bean', 'Lima bean', 'Common bean', 'Date', 'Black chokeberry', 'Anise', 'Pine nut', 'Pepper (Spice)', 'Pistachio', 'Common pea', 'Purslane', 'Prunus (Cherry, Plum)', 'Apricot', 'Sweet cherry', 'Sour cherry', 'European plum', 'Almond', 'Peach', 'Guava', 'Pomegranate', 'Pear', 'Radish', 'Garden rhubarb', 'Blackcurrant', 'Redcurrant', 'Gooseberry', 'Watercress', 'Rosemary', 'Rubus (Blackberry, Raspberry)', 'Cloudberry', 'Red raspberry', 'Black raspberry', 'Sorrel', 'Common sage', 'Black elderberry', 'Summer savory', 'Winter savory', 'Rye', 'Sesame', 'Garden tomato', 'Cherry tomato', 'Garden tomato (var.)', 'Eggplant', 'Potato', 'Rowanberry', 'Sorghum', 'Spinach', 'Cloves', 'Tamarind', 'Dandelion', 'Cocoa bean', 'Common thyme', 'Linden', 'Small-leaf linden', 'Fenugreek', 'Common wheat', 'Vaccinium (Blueberry, Cranberry, Huckleberry)', 'Lowbush blueberry', 'Sparkleberry', 'Highbush blueberry', 'American cranberry', 'Bilberry', 'Lingonberry', 'Vanilla', 'Common verbena', 'Broad bean', 'Adzuki bean', 'Gram bean', 'Mung bean', 'Climbing bean', 'Cowpea', 'Muscadine grape', 'Common grape', 'Corn', 'Ginger', 'Arctic blackberry', 'Banana', 'Bayberry', "Elliott's blueberry", 'Canada blueberry', 'Bog bilberry', 'Buffalo currant', 'Celeriac', 'Celery stalks', 'Chinese chives', 'European cranberry', 'Deerberry', 'Ginseng', 'Cascade huckleberry', 'Oval-leaf huckleberry', 'Evergreen huckleberry', 'Red huckleberry', 'Longan', 'Macadamia nut (M. tetraphylla)', 'Garden onion (var.)', 'Summer grape', 'Fox grape', 'Nectarine', 'Peach (var.)', 'Pepper (C. baccatum)', 'Pepper (C. chinense)', 'Pepper (Capsicum)', 'Rambutan', 'Red rice', 'Annual wild rice', 'Swiss chard', 'Lemon thyme', 'Tronchuda cabbage', 'Japanese walnut', 'Welsh onion', 'Hard wheat', 'Shallot', 'Rocket salad', 'Carrot', 'Triticale', 'Black cabbage', 'Half-highbush blueberry', 'Celery leaves', 'Chicory leaves', 'Komatsuna', 'Pak choy', 'Napa cabbage', 'Chicory roots', 'Grapefruit/Pummelo hybrid', 'Grapefruit', 'Jostaberry', 'Kai-lan', 'Italian oregano', 'Oxheart cabbage', 'Daikon radish', 'Black radish', 'Radish (var.)', 'Red beetroot', 'Sweet rowanberry', 'Pineappple sage', 'Skunk currant', ' ...

# %%
# How many?
len(foods)
# Out:
# 907

# %%
# Some of the compound words can be split because they would be part of the ingridents.
food_list = []
for food in foods:
    food_list.append(food.split())

# %%
# Iterate through to get each in a list.
common_foods = []
for foods in food_list:
    for food in foods:
        common_foods.append(food.lower())

# %%
len(common_foods)
# Out:
# 1548

# %%
# Get only the unique foods.
separate_common_foods = list(set(common_foods))

# %%
len(separate_common_foods)
# Out:
# 952

# %%
# Now, iterate through the 'filtered_foods'and if a food matches one that is in the
# 'separate_common_foods' then put that food in a list.

new_foods = []
for i in range(len(separate_common_foods)):
    for j in range(len(filtered_foods)):
        if separate_common_foods[i] == filtered_foods[j]:
            new_foods.append(filtered_foods[j])

# %%
# How many foods now?
len(new_foods)
# Out:
# 458

# %%
print(new_foods)
# Out:
# ['nectarine', 'jicama', 'snow', 'pudding', 'tostada', 'savory', 'products', 'guava', 'plantain', 'ground', 'domestic', 'pepper', 'scarlet', 'sugar', 'bar', 'cooking', 'cucumber', 'kelp', 'brown', 'sheep', 'kiwi', 'chip', 'mixed', 'filling', 'crab', 'raisin', 'grits', 'ravioli', 'citrus', 'dried', 'mint', 'de', 'tamarind', 'yam', 'custard', 'sorrel', 'barley', 'pecan', 'bamboo', 'gooseberry', 'amaranth', 'pot', 'rhubarb', 'dandelion', 'catfish', 'lingonberry', 'sorghum', 'salad', 'yellow', 'vegetable', 'baby', 'burdock', 'rum', 'mousse', 'black-eyed', 'apricot', 'kale', 'celeriac', 'turkey', 'cracker', 'flour', 'vitamin', 'dog', 'heart', 'plum', 'banana', 'boysenberry', 'cardamom', 'agave', 'maitake', 'dish', 'fruits', 'beech', 'buttermilk', 'corn', 'fig', 'strawberry', 'food', 'sherry', 'bread', 'cumin', 'hen', 'oregano', 'arepa', 'savoy', 'cereal', 'pan', 'quail', 'chives', 'parsnip', 'radish', 'dough', 'mandarin', 'juice', '+', 'arctic', 'grouper', 'almond', 'tomato', 'artichoke', 'pea', 'cashew', 'allspice', 'halibut', 'pita', 'broccoli', 'sauce', 'pomegranate', 'milk', 'pineapple', 'wheat', 'tarragon', 'italian', 'roots', 'chicken', 'salmon', 'lotus', 'pink', 'spelt', 'quince', 'avocado', 'eggplant', 'oil', 'icing', 'sandwich', 'powder', 'multigrain', 'meatloaf', 'duck', 'honey', 'fruit', 'peach', 'root', 'winter', 'chicory', 'pancake', 'cabbage', 'fennel', 'product', 'gratin', 'millet', 'curry', 'stew', 'asparagus', 'roll', 'zucchini', 'monkfish', 'toffee', 'soy', 'rapini', 'white', 'persimmon', 'cold', 'relish', 'ginger', 'crust', 'bass', 'goose', 'pumpkin', 'lime', 'coconut', 'sausage', 'yellowfin', 'fats', 'spinach', 'fermented', 'whisky', 'dressing', 'cherry', 'kohlrabi', 'oat', 'molasses', 'carrot', 'chayote', 'mushroom', 'cider', 'jack', 'cake', 'globe', 'condensed', 'turmeric', 'summer', 'turbot', 'tapioca', 'peppermint', 'wax', 'cornbread', 'rye', 'shrimp', 'swordfish', 'burger', 'pie', 'towel', 'chervil', 'capers', 'cauliflower', 'trout', 'biscuit', 'pollock', 'cuttlefish', 'great', 'egg', 'apple', 'peanut', 'nutmeg', 'leaf', 'vodka', 'cream', 'bean', 'vanilla', 'salsify', 'pastry', 'currant', 'marshmallow', 'adobo', 'striped', 'acorn', 'bitter', 'quinoa', 'balm', 'hazelnut', 'wasabi', 'star', 'silver', 'nutritional', 'tree', 'bluefish', 'tea', 'crisp', 'fish', 'boar', 'salt', 'cinnamon', 'soup', 'pearl', 'snail', 'shoots', 'cut', 'buffalo', 'coffee', 'water', 'mushrooms', 'sunflower', 'margarine', 'purslane', 'oyster', 'wild', 'hard', 'roe', 'rosemary', 'sea', 'romaine', 'spices', 'leche', 'dumpling', 'wonton', 'whey', 'vegetarian', 'sturgeon', 'enchilada', 'dessert', 'okra', 'brussel', 'cone', 'napa', 'broad', 'grape', 'miso', 'foods', 'poppy', 'asian', 'gum', 'sole', 'choy', 'phyllo', 'anchovy', 'herbs', 'leaves', 'french', 'pistachio', 'veggie', 'basil', 'persian', 'cranberry', 'fat', 'arrowroot', 'sour', 'chocolate', 'yogurt', 'buckwheat', 'chickpea', 'leek', 'mackerel', 'daikon', 'hickory', 'frozen', 'mocha', 'spanish', 'raspberry', 'blue', 'chanterelle', 'watercress', 'canola', 'candy', 'cloves', 'lard', 'rainbow', 'pear', 'couscous', 'shallot', 'potato', 'saffron', 'cocktail', 'pine', 'bell', 'olive', 'chili', 'fungus', 'sweet', 'chestnut', 'marjoram', 'northern', 'orange', 'bagel', 'spread', 'stuffing', 'mix', 'onion', 'beer', 'chia', 'sesame', 'breakfast', 'whitefish', 'sake', 'shiitake', 'butternut', 'cress', 'ice', 'kefir', 'snapper', 'toast', 'mango', 'safflower', 'macaroni', 'pizza', 'cod', 'gin', 'empanada', 'ketchup', 'vegetables', 'haddock', 'celery', 'king', 'thyme', 'bulgur', 'hot', 'meat', 'black', 'mountain', 'stalks', 'new', 'common', 'coriander', 'lasagna', 'lima', 'seed', 'walnut', 'turnip', 'marzipan', 'parsley', 'epazote', 'squid', 'blackberry', 'lobster', 'freshwater', 'substitute', 'topping', 'bouillon', 'nuts', 'gelatin', 'mung', 'kombu', 'blueberry', 'goat', 'vinegar', 'ear', 'date', 'lemon', 'butter', 'evaporated', 'bison', 'palm', 'cheese', 'shell', 'oriental', 'papaya', 'passion', ...

# %%
# Convert the list to a dictionary
food_dict = {k: v for k, v in enumerate(new_foods)}
print(food_dict)
# Out:
# {0: 'nectarine', 1: 'jicama', 2: 'snow', 3: 'pudding', 4: 'tostada', 5: 'savory', 6: 'products', 7: 'guava', 8: 'plantain', 9: 'ground', 10: 'domestic', 11: 'pepper', 12: 'scarlet', 13: 'sugar', 14: 'bar', 15: 'cooking', 16: 'cucumber', 17: 'kelp', 18: 'brown', 19: 'sheep', 20: 'kiwi', 21: 'chip', 22: 'mixed', 23: 'filling', 24: 'crab', 25: 'raisin', 26: 'grits', 27: 'ravioli', 28: 'citrus', 29: 'dried', 30: 'mint', 31: 'de', 32: 'tamarind', 33: 'yam', 34: 'custard', 35: 'sorrel', 36: 'barley', 37: 'pecan', 38: 'bamboo', 39: 'gooseberry', 40: 'amaranth', 41: 'pot', 42: 'rhubarb', 43: 'dandelion', 44: 'catfish', 45: 'lingonberry', 46: 'sorghum', 47: 'salad', 48: 'yellow', 49: 'vegetable', 50: 'baby', 51: 'burdock', 52: 'rum', 53: 'mousse', 54: 'black-eyed', 55: 'apricot', 56: 'kale', 57: 'celeriac', 58: 'turkey', 59: 'cracker', 60: 'flour', 61: 'vitamin', 62: 'dog', 63: 'heart', 64: 'plum', 65: 'banana', 66: 'boysenberry', 67: 'cardamom', 68: 'agave', 69: 'maitake', 70: 'dish', 71: 'fruits', 72: 'beech', 73: 'buttermilk', 74: 'corn', 75: 'fig', 76: 'strawberry', 77: 'food', 78: 'sherry', 79: 'bread', 80: 'cumin', 81: 'hen', 82: 'oregano', 83: 'arepa', 84: 'savoy', 85: 'cereal', 86: 'pan', 87: 'quail', 88: 'chives', 89: 'parsnip', 90: 'radish', 91: 'dough', 92: 'mandarin', 93: 'juice', 94: '+', 95: 'arctic', 96: 'grouper', 97: 'almond', 98: 'tomato', 99: 'artichoke', 100: 'pea', 101: 'cashew', 102: 'allspice', 103: 'halibut', 104: 'pita', 105: 'broccoli', 106: 'sauce', 107: 'pomegranate', 108: 'milk', 109: 'pineapple', 110: 'wheat', 111: 'tarragon', 112: 'italian', 113: 'roots', 114: 'chicken', 115: 'salmon', 116: 'lotus', 117: 'pink', 118: 'spelt', 119: 'quince', 120: 'avocado', 121: 'eggplant', 122: 'oil', 123: 'icing', 124: 'sandwich', 125: 'powder', 126: 'multigrain', 127: 'meatloaf', 128: 'duck', 129: 'honey', 130: 'fruit', 131: 'peach', 132: 'root', 133: 'winter', 134: 'chicory', 135: 'pancake', 136: 'cabbage', 137: 'fennel', 138: 'product', 139: 'gratin', 140: 'millet', 141: 'curry', 142: 'stew', 143: 'asparagus', 144: 'roll', 145: 'zucchini', 146: 'monkfish', 147: 'toffee', 148: 'soy', 149: 'rapini', 150: 'white', 151: 'persimmon', 152: 'cold', 153: 'relish', 154: 'ginger', 155: 'crust', 156: 'bass', 157: 'goose', 158: 'pumpkin', 159: 'lime', 160: 'coconut', 161: 'sausage', 162: 'yellowfin', 163: 'fats', 164: 'spinach', 165: 'fermented', 166: 'whisky', 167: 'dressing', 168: 'cherry', 169: 'kohlrabi', 170: 'oat', 171: 'molasses', 172: 'carrot', 173: 'chayote', 174: 'mushroom', 175: 'cider', 176: 'jack', 177: 'cake', 178: 'globe', 179: 'condensed', 180: 'turmeric', 181: 'summer', 182: 'turbot', 183: 'tapioca', 184: 'peppermint', 185: 'wax', 186: 'cornbread', 187: 'rye', 188: 'shrimp', 189: 'swordfish', 190: 'burger', 191: 'pie', 192: 'towel', 193: 'chervil', 194: 'capers', 195: 'cauliflower', 196: 'trout', 197: 'biscuit', 198: 'pollock', 199: 'cuttlefish', 200: 'great', 201: 'egg', 202: 'apple', 203: 'peanut', 204: 'nutmeg', 205: 'leaf', 206: 'vodka', 207: 'cream', 208: 'bean', 209: 'vanilla', 210: 'salsify', 211: 'pastry', 212: 'currant', 213: 'marshmallow', 214: 'adobo', 215: 'striped', 216: 'acorn', 217: 'bitter', 218: 'quinoa', 219: 'balm', 220: 'hazelnut', 221: 'wasabi', 222: 'star', 223: 'silver', 224: 'nutritional', 225: 'tree', 226: 'bluefish', 227: 'tea', 228: 'crisp', 229: 'fish', 230: 'boar', 231: 'salt', 232: 'cinnamon', 233: 'soup', 234: 'pearl', 235: 'snail', 236: 'shoots', 237: 'cut', 238: 'buffalo', 239: 'coffee', 240: 'water', 241: 'mushrooms', 242: 'sunflower', 243: 'margarine', 244: 'purslane', 245: 'oyster', 246: 'wild', 247: 'hard', 248: 'roe', 249: 'rosemary', 250: 'sea', 251: 'romaine', 252: 'spices', 253: 'leche', 254: 'dumpling', 255: 'wonton', 256: 'whey', 257: 'vegetarian', 258: 'sturgeon', 259: 'enchilada', 260: 'dessert', 261: 'okra', 262: 'brussel', 263: 'cone', 264: 'napa', 265: 'broad', 266: 'grape', 267: 'miso', 268: 'foods', 269: 'poppy', 270: 'asian', 271: 'gum', 272: 'sole', 273: 'choy', ...

# %% [markdown]
# ## Summary for ingredients.
# ---
# - There were 182,402 are words associated with the ingredients.
# - Using regex qnd getting unique words these were reduced to 5,592 words associated with the ingredients.
# - Using nltk, a common food list, and a food measurement list these 5,592 were reduced to 458 words associated with the ingredients.
